# %%
# %automagic
# Out:
# Automagic is ON, % prefix IS NOT needed for line magics.

# %%
import pandas as pd
import numpy as np

# %%
folder = '/home/dsc/Repos/TFM_Accident_reduction_plan_in_the_city_of_Madrid'
# !ls {folder}
# Out:
# 01_Originals_data  02_Desarrollo  README.md

# %%
import os
os.getcwd()
# Out:
# '/home/dsc/Repos/TFM_Accident_reduction_plan_in_the_city_of_Madrid'

# %%
os.chdir(folder)
os.getcwd()
# Out:
# '/home/dsc/Repos/TFM_Accident_reduction_plan_in_the_city_of_Madrid'

# %%
# Read from excel file with column names stipulated:
# FECHA	RANGO HORARIO	DIA SEMANA	DISTRITO	LUGAR ACCIDENTE	Nº	Nº PARTE	CPFA Granizo	CPFA Hielo	CPFA Lluvia	CPFA Niebla	CPFA Seco	CPFA Nieve	CPSV Mojada	CPSV Aceite	CPSV Barro	CPSV Grava Suelta	CPSV Hielo	CPSV Seca Y Limpia	Nº VICTIMAS *	TIPO ACCIDENTE	Tipo Vehiculo	TIPO PERSONA	SEXO	LESIVIDAD	Tramo Edad
# x
# FECHA   RANGO_HORARIO   DIA_SEMANA      DISTRITO        LUGAR_ACCIDENTE BORRAR  BORRAR          BORRAR          BORRAR          BORRAR          BORRAR          BORRAR          BORRAR          BORRAR          BORRAR          BORRAR          BORRAR                  BORRAR          BORRAR                  NUM_PERSONAS    TIPO_ACCIDENTE  TIPO_VEHICULO   TIPO_PERSONA    SEXO    LESIVIDAD       TRAMO_EDAD

df_from_xls = pd.read_excel('./01_Originals_data/2010_Accidentalidad.xlsx',
                     sheet_name='LISTADO DE ACCIDENTES MENSUALES',
                     index_col=None,
                     names=['FECHA', 'RANGO_HORARIO', 'DIA_SEMANA', 'DISTRITO', 'BORRAR', 'BORRAR', 'BORRAR', 'BORRAR', 'BORRAR', 'BORRAR', 'BORRAR', 'BORRAR', 'BORRAR', 'BORRAR', 'BORRAR', 'BORRAR', 'BORRAR', 'BORRAR', 'BORRAR', 'NUM_PERSONAS', 'TIPO_ACCIDENTE', 'TIPO_VEHICULO', 'TIPO_PERSONA', 'SEXO', 'LESIVIDAD', 'TRAMO_EDAD'])

# %%
df_from_xls.head()
# Out:
#        FECHA     RANGO_HORARIO DIA_SEMANA                        DISTRITO  \
# 0 2010-01-01  DE 00:00 A 00:59    VIERNES  CHAMARTIN
# 1 2010-01-01  DE 00:00 A 00:59    VIERNES  CHAMARTIN
# 2 2010-01-01  DE 00:00 A 00:59    VIERNES  CHAMARTIN
# 3 2010-01-01    DE 1:00 A 1:59    VIERNES  PUENTE DE VALLECAS
# 4 2010-01-01    DE 1:00 A 1:59    VIERNES  PUENTE DE VALLECAS
#
#                                               BORRAR BORRAR    BORRAR BORRAR  \
# 0  CALLE DE CARTAGENA NUM                        ...    104  2010/135     NO
# 1  CALLE DE CARTAGENA NUM                        ...    104  2010/135     NO
# 2  CALLE DE CARTAGENA NUM                        ...    104  2010/135     NO
# 3  AUTOVIA  M-30 CALZADA 2 KM.                   ...  10200   2010/94     NO
# 4  AUTOVIA  M-30 CALZADA 2 KM.                   ...  10200   2010/94     NO
#
#   BORRAR BORRAR       ...        BORRAR BORRAR BORRAR NUM_PERSONAS  \
# 0     NO     SI       ...            NO     NO     NO            1
# 1     NO     SI       ...            NO     NO     NO            1
# 2     NO     SI       ...            NO     NO     NO            1
# 3     NO     NO       ...            NO     NO     NO            7
# 4     NO     NO       ...            NO     NO     NO            7
#
#                              TIPO_ACCIDENTE  \
# 0  COLISIÓN DOBLE
# 1  COLISIÓN DOBLE
# 2  COLISIÓN DOBLE
# 3  COLISIÓN MÚLTIPLE
# 4  COLISIÓN MÚLTIPLE
#
#                               TIPO_VEHICULO  \
# 0  TURISMO
# 1  TURISMO
# 2  TURISMO
# 3                               NO ASIGNADO
# 4                               NO ASIGNADO
#
#                                TIPO_PERSONA    SEXO  \
# 0                                 CONDUCTOR  HOMBRE
# 1                                 CONDUCTOR  HOMBRE
# 2  VIAJERO                                    MUJER
# 3  VIAJERO                                    MUJER
# 4  VIAJERO                                    MUJER
#
#                                   LESIVIDAD       TRAMO_EDAD
# 0  IL                                        DE 18 A 20 AÑOS
# 1  IL                                        DE 50 A 54 AÑOS
# 2  HL                                        DE 40 A 44 AÑOS
# 3  HL                                        DE 25 A 29 AÑOS
# 4  HL                                        DE 30 A 34 ANOS
#
# [5 rows x 26 columns]

# %%
df_from_xls.shape
# Out:
# (26578, 26)

# %%
df_from_xls.duplicated().sum()
# Out:
# 874

# %%
# Comprobar valores nulos
df_from_xls.isnull().sum()
# Out:
# FECHA             0
# RANGO_HORARIO     0
# DIA_SEMANA        0
# DISTRITO          0
# BORRAR            0
# BORRAR            0
# BORRAR            0
# BORRAR            0
# BORRAR            0
# BORRAR            0
# BORRAR            0
# BORRAR            0
# BORRAR            0
# BORRAR            0
# BORRAR            0
# BORRAR            0
# BORRAR            0
# BORRAR            0
# BORRAR            0
# NUM_PERSONAS      0
# TIPO_ACCIDENTE    0
# TIPO_VEHICULO     0
# TIPO_PERSONA      0
# SEXO              0
# LESIVIDAD         0
# TRAMO_EDAD        0
# dtype: int64

# %%
# borrar columnas sobrantes:
del df_from_xls['BORRAR']

# %%
df_from_xls.shape
# Out:
# (26578, 11)

# %%
df_from_xls.head(20)
# Out:
#         FECHA     RANGO_HORARIO DIA_SEMANA                        DISTRITO  \
# 0  2010-01-01  DE 00:00 A 00:59    VIERNES  CHAMARTIN
# 1  2010-01-01  DE 00:00 A 00:59    VIERNES  CHAMARTIN
# 2  2010-01-01  DE 00:00 A 00:59    VIERNES  CHAMARTIN
# 3  2010-01-01    DE 1:00 A 1:59    VIERNES  PUENTE DE VALLECAS
# 4  2010-01-01    DE 1:00 A 1:59    VIERNES  PUENTE DE VALLECAS
# 5  2010-01-01    DE 1:00 A 1:59    VIERNES  PUENTE DE VALLECAS
# 6  2010-01-01    DE 1:00 A 1:59    VIERNES  PUENTE DE VALLECAS
# 7  2010-01-01    DE 1:00 A 1:59    VIERNES  PUENTE DE VALLECAS
# 8  2010-01-01    DE 1:00 A 1:59    VIERNES  PUENTE DE VALLECAS
# 9  2010-01-01    DE 1:00 A 1:59    VIERNES  PUENTE DE VALLECAS
# 10 2010-01-01    DE 1:00 A 1:59    VIERNES  PUENTE DE VALLECAS
# 11 2010-01-01    DE 2:00 A 2:59    VIERNES  CHAMBERI
# 12 2010-01-01    DE 2:00 A 2:59    VIERNES  CHAMBERI
# 13 2010-01-01    DE 4:00 A 4:59    VIERNES  RETIRO
# 14 2010-01-01    DE 4:00 A 4:59    VIERNES  RETIRO
# 15 2010-01-01    DE 4:00 A 4:59    VIERNES  RETIRO
# 16 2010-01-01    DE 4:00 A 4:59    VIERNES  RETIRO
# 17 2010-01-01    DE 4:00 A 4:59    VIERNES  RETIRO
# 18 2010-01-01    DE 4:00 A 4:59    VIERNES  RETIRO
# 19 2010-01-01    DE 4:00 A 4:59    VIERNES  RETIRO
#
#     NUM_PERSONAS                            TIPO_ACCIDENTE  \
# 0              1  COLISIÓN DOBLE
# 1              1  COLISIÓN DOBLE
# 2              1  COLISIÓN DOBLE
# 3              7  COLISIÓN MÚLTIPLE
# 4              7  COLISIÓN MÚLTIPLE
# 5              7  COLISIÓN MÚLTIPLE
# 6              7  COLISIÓN MÚLTIPLE
# 7              7  COLISIÓN MÚLTIPLE
# 8              7  COLISIÓN MÚLTIPLE
# 9              7  COLISIÓN MÚLTIPLE
# 10             7  COLISIÓN MÚLTIPLE
# 11             1  COLISIÓN DOBLE
# 12             1  COLISIÓN DOBLE
# 13             7  COLISIÓN MÚLTIPLE
# 14             7  COLISIÓN MÚLTIPLE
# 15             7  COLISIÓN MÚLTIPLE
# 16             7  COLISIÓN MÚLTIPLE
# 17             7  COLISIÓN MÚLTIPLE
# 18             7  COLISIÓN MÚLTIPLE
# 19             7  COLISIÓN MÚLTIPLE
#
#                                TIPO_VEHICULO  \
# 0   TURISMO
# 1   TURISMO
# 2   TURISMO
# 3                                NO ASIGNADO
# 4                                NO ASIGNADO
# 5                                NO ASIGNADO
# 6                                NO ASIGNADO
# 7   TURISMO
# 8   TURISMO
# 9   TURISMO
# 10  FURGONETA
# 11  MOTOCICLETA
# 12  AUTO-TAXI
# 13                               NO ASIGNADO
# 14                               NO ASIGNADO
# 15  TURISMO
# 16  TURISMO
# 17  TURISMO
# 18  TURISMO
# 19  TURISMO
#
#                                 TIPO_PERSONA    SEXO  \
# 0                                  CONDUCTOR  HOMBRE
# 1                                  CONDUCTOR  HOMBRE
# 2   VIAJERO                                    MUJER
# 3   VIAJERO                                    MUJER
# 4   VIAJERO                                    MUJER
# 5   VIAJERO                                    MUJER
# 6   VIAJERO                                    MUJER
# 7                                  CONDUCTOR  HOMBRE
# 8                                  CONDUCTOR   MUJER
# 9   VIAJERO                                    MUJER
# 10                                 CONDUCTOR  HOMBRE
# 11                                 CONDUCTOR  HOMBRE
# 12                                 CONDUCTOR  HOMBRE
# 13  TESTIGO                                   HOMBRE
# 14  TESTIGO                                   HOMBRE
# 15                                 CONDUCTOR  HOMBRE
# 16  VIAJERO                                   HOMBRE
# 17  VIAJERO                                    MUJER
# 18  VIAJERO                                    MUJER
# 19  VIAJERO                                    MUJER
#
#                                    LESIVIDAD       TRAMO_EDAD
# 0   IL                                        DE 18 A 20 AÑOS
# 1   IL                                        DE 50 A 54 AÑOS
# 2   HL                                        DE 40 A 44 AÑOS
# 3   HL                                        DE 25 A 29 AÑOS
# 4   HL                                        DE 30 A 34 ANOS
# 5   HL                                        DE 25 A 29 AÑOS
# 6   HL                                        DE 25 A 29 AÑOS
# 7   IL                                        DE 25 A 29 AÑOS
# 8   HL                                        DE 25 A 29 AÑOS
# 9   HL                                        DE 21 A 24 AÑOS
# 10  HL                                        DE 25 A 29 AÑOS
# 11  HL                                        DE 35 A 39 AÑOS
# 12  IL                                        DE 35 A 39 AÑOS
# 13  IL                                        DE 25 A 29 AÑOS
# 14  IL                                        DE 30 A 34 ANOS
# 15  HL                                        DE 25 A 29 AÑOS
# 16  IL                                        DE 30 A 34 ANOS
# 17  IL                                        DE 18 A 20 AÑOS
# 18  HG                                        DE 21 A 24 AÑOS
# 19  HL                                        DE 21 A 24 AÑOS

# %%
df_from_xls.dtypes
# Out:
# FECHA             datetime64[ns]
# RANGO_HORARIO             object
# DIA_SEMANA                object
# DISTRITO                  object
# NUM_PERSONAS               int64
# TIPO_ACCIDENTE            object
# TIPO_VEHICULO             object
# TIPO_PERSONA              object
# SEXO                      object
# LESIVIDAD                 object
# TRAMO_EDAD                object
# dtype: object

# %%
df_from_xls.columns
# Out:
# Index(['FECHA', 'RANGO_HORARIO', 'DIA_SEMANA', 'DISTRITO', 'NUM_PERSONAS',
#        'TIPO_ACCIDENTE', 'TIPO_VEHICULO', 'TIPO_PERSONA', 'SEXO', 'LESIVIDAD',
#        'TRAMO_EDAD'],
#       dtype='object')

# %%
df_from_xls.fillna("NO_ASIGNADO", inplace=True)

# %%
# Comprobar valores nulos
df_from_xls.isnull().sum()
# Out:
# FECHA             0
# RANGO_HORARIO     0
# DIA_SEMANA        0
# DISTRITO          0
# NUM_PERSONAS      0
# TIPO_ACCIDENTE    0
# TIPO_VEHICULO     0
# TIPO_PERSONA      0
# SEXO              0
# LESIVIDAD         0
# TRAMO_EDAD        0
# dtype: int64

# %%
df_from_xls.duplicated().sum()
# Out:
# 877

# %%
df_dupls = df_from_xls[df_from_xls.duplicated(keep=False)]
df_dupls_values = df_dupls.groupby(df_dupls.columns.tolist()).apply(lambda x: x.index.tolist()).values.tolist()
df_dupls_relation = df_dupls.groupby(df_dupls.columns.tolist()).apply(lambda x: x.index.tolist())

# %%
type(df_dupls_values)
# Out:
# list

# %%
type(df_dupls_relation)
# Out:
# pandas.core.series.Series

# %%
df_dupls_values
# Out:
# [[3, 5, 6],
#  [31, 32],
#  [87, 88],
#  [137, 138],
#  [160, 161],
#  [257, 258, 259, 260],
#  [301, 302],
#  [356, 358],
#  [405, 406],
#  [426, 427],
#  [433, 435],
#  [497, 498],
#  [499, 501],
#  [507, 508],
#  [567, 568],
#  [587, 588],
#  [593, 594],
#  [649, 650, 651, 652],
#  [685, 686],
#  [734, 735, 736],
#  [742, 743],
#  [774, 775],
#  [788, 789],
#  [796, 797, 798],
#  [817, 818],
#  [872, 873],
#  [877, 879, 880, 881],
#  [941, 945],
#  [1134, 1135],
#  [1037, 1038],
#  [1183, 1184],
#  [1255, 1256],
#  [1268, 1269, 1270, 1271, 1272],
#  [1204, 1205, 1206],
#  [1331, 1332],
#  [1417, 1418],
#  [1419, 1420],
#  [1453, 1454, 1455, 1456],
#  [1519, 1520, 1521],
#  [1539, 1540],
#  [1601, 1602],
#  [1743, 1744, 1745],
#  [1754, 1755],
#  [1700, 1701, 1702],
#  [1803, 1804],
#  [1840, 1841],
#  [1870, 1871],
#  [1880, 1881],
#  [1886, 1887],
#  [1919, 1920],
#  [1953, 1954],
#  [1891, 1892],
#  [2070, 2071, 2072],
#  [2080, 2081, 2082, 2083],
#  [2102, 2103],
#  [2025, 2026],
#  [2030, 2031],
#  [2175, 2176],
#  [2183, 2184],
#  [2186, 2187, 2188],
#  [2253, 2254],
#  [2313, 2314],
#  [2327, 2328, 2330],
#  [2295, 2296],
#  [2303, 2304],
#  [2399, 2401, 2402],
#  [2432, 2433, 2434],
#  [2542, 2544],
#  [2658, 2659],
#  [2671, 2672],
#  [2705, 2706],
#  [2734, 2735],
#  [2746, 2747],
#  [2820, 2821],
#  [2898, 2899, 2900],
#  [2927, 2928],
#  [2945, 2946],
#  [2960, 2961],
#  [2883, 2884],
#  [3005, 3006],
#  [3073, 3074],
#  [3083, 3084],
#  [3099, 3100],
#  [3102, 3104],
#  [3132, 3133],
#  [3227, 3228],
#  [3238, 3239],
#  [3236, 3237],
#  [3194, 3195],
#  [3198, 3199, 3200],
#  [3203, 3204],
#  [3210, 3211],
#  [3264, 3265],
#  [3269, 3272],
#  [3322, 3323],
#  [3333, 3334],
#  [3278, 3279],
#  [3285, 3286],
#  [3351, 3352],
#  [22736, 22738],
#  [22741, 22742, 22743],
#  [22816, 22817],
#  [22835, 22836],
#  [22996, 22997],
#  [22926, 22927],
#  [23023, 23024, 23025],
#  [23173, 23174],
#  [23097, 23098, 23100],
#  [23106, 23107],
#  [23191, 23192, 23193],
#  [23268, 23269],
#  [23273, 23274],
#  [23386, 23388, 23391, 23392],
#  [23410, 23411],
#  [23493, 23495],
#  [23581, 23582],
#  [23687, 23688, 23689, 23690],
#  [23699, 23700],
#  [23780, 23781, 23782],
#  [23803, 23807],
#  [23810, 23811],
#  [23738, 23739],
#  [23865, 23866],
#  [23820, 23822],
#  [23828, 23829],
#  [23838, 23839],
#  [23934, 23935],
#  [23991, 23992],
#  [24055, 24056],
#  [23997, 23998],
#  [24181, 24182],
#  [24326, 24327],
#  [24335, 24336],
#  [24284, 24285],
#  [24417, 24418],
#  [24446, 24447],
#  [24376, 24377],
#  [24380, 24384],
#  [24390, 24391],
#  [24398, 24400],
#  [24460, 24461, 24462],
#  [24468, 24469],
#  [24463, 24465, 24466, 24467],
#  [24470, 24471],
#  [24498, 24500],
#  [24502, 24503],
#  [24505, 24507],
#  [24476, 24478],
#  [24586, 24587, 24588],
#  [24599, 24600],
#  [24610, 24611],
#  [24613, 24615],
#  [24561, 24562],
#  [24569, 24571, 24573],
#  [24568, 24570],
#  [24654, 24655],
#  [24666, 24667],
#  [24719, 24720],
#  [24757, 24758],
#  [24844, 24846],
#  [24765, 24767],
#  [24976, 24977],
#  [25001, 25002],
#  [25004, 25005],
#  [25013, 25014],
#  [25017, 25018],
#  [25047, 25048],
#  [25139, 25140, 25141],
#  [25107, 25108, 25109],
#  [25233, 25235],
#  [25229, 25230],
#  [25431, 25433],
#  [25436, 25437],
#  [25446, 25447],
#  [25390, 25391],
#  [25625, 25627],
#  [25642, 25643],
#  [25605, 25608],
#  [25614, 25615],
#  [25713, 25714],
#  [25875, 25876],
#  [25848, 25849],
#  [25927, 25928],
#  [25940, 25941],
#  [25942, 25943],
#  [25951, 25952],
#  [25967, 25968],
#  [26116, 26117],
#  [26133, 26134, 26135],
#  [26137, 26138],
#  [26146, 26147, 26148],
#  [26060, 26061],
#  [26186, 26187],
#  [26195, 26196],
#  [26233, 26234],
#  [26279, 26280, 26282],
#  [26283, 26284],
#  [26281, 26285],
#  [26294, 26295],
#  [26302, 26303],
#  [26346, 26347],
#  [26400, 26401],
#  [26408, 26409],
#  [26471, 26472],
#  [26509, 26510],
#  [26526, 26528]]

# %%
df_dupls_relation
# Out:
# FECHA       RANGO_HORARIO     DIA_SEMANA  DISTRITO                        NUM_PERSONAS  TIPO_ACCIDENTE                            TIPO_VEHICULO                             TIPO_PERSONA                              SEXO         LESIVIDAD                                 TRAMO_EDAD
# 2010-01-01  DE 1:00 A 1:59    VIERNES     PUENTE DE VALLECAS              7             COLISIÓN MÚLTIPLE                         NO ASIGNADO                               VIAJERO                                   MUJER        HL                                        DE 25 A 29 AÑOS                   [3, 5, 6]
#             DE 9:00 A 9:59    VIERNES     SALAMANCA                       1             CHOQUE CON OBJETO FIJO                    NO ASIGNADO                               TESTIGO                                   HOMBRE       IL                                        
# 2010-12-31  DE 6:00 A 6:59    VIERNES     ARGANZUELA                      3             COLISIÓN DOBLE                            TURISMO                                   VIAJERO                                   HOMBRE       HL                                        DE 30 A 34 ANOS              [26526, 26528]
# Length: 719, dtype: object

# %%
#df_from_xls.iloc[3]

# %%
#df_from_xls.iloc[5]

# %%
#df_from_xls.iloc[6]

# %%
#df_dupls_relation = pd.DataFrame(df_dupls_relation)
#df_dupls_relation.count()

# %%
#df_dupls_relation.head()

# %%
# strip leading and trailing space
# no string: df_from_xls['FECHA'] = df_from_xls['FECHA'].str.strip()
df_from_xls['RANGO_HORARIO'] = df_from_xls['RANGO_HORARIO'].str.strip()
df_from_xls['DIA_SEMANA'] = df_from_xls['DIA_SEMANA'].str.strip()
df_from_xls['DISTRITO'] = df_from_xls['DISTRITO'].str.strip()
# no string: df_from_xls['NUM_PERSONAS'] = df_from_xls['NUM_PERSONAS'].str.strip()
df_from_xls['TIPO_ACCIDENTE'] = df_from_xls['TIPO_ACCIDENTE'].str.strip()
df_from_xls['TIPO_VEHICULO'] = df_from_xls['TIPO_VEHICULO'].str.strip()
df_from_xls['TIPO_PERSONA'] = df_from_xls['TIPO_PERSONA'].str.strip()
df_from_xls['SEXO'] = df_from_xls['SEXO'].str.strip()
df_from_xls['LESIVIDAD'] = df_from_xls['LESIVIDAD'].str.strip()
df_from_xls['TRAMO_EDAD'] = df_from_xls['TRAMO_EDAD'].str.strip()

# %%
df_from_xls["FECHA"].unique()
# Out:
# array(['2010-01-01T00:00:00.000000000', '2010-01-02T00:00:00.000000000',
#        '2010-01-03T00:00:00.000000000', '2010-01-04T00:00:00.000000000',
#        '2010-01-05T00:00:00.000000000', '2010-01-06T00:00:00.000000000',
#        '2010-01-07T00:00:00.000000000', '2010-01-08T00:00:00.000000000',
#        '2010-01-09T00:00:00.000000000', '2010-01-10T00:00:00.000000000',
#        '2010-01-11T00:00:00.000000000', '2010-01-12T00:00:00.000000000',
#        '2010-01-13T00:00:00.000000000', '2010-01-14T00:00:00.000000000',
#        '2010-01-15T00:00:00.000000000', '2010-01-16T00:00:00.000000000',
#        '2010-01-17T00:00:00.000000000', '2010-01-18T00:00:00.000000000',
#        '2010-01-19T00:00:00.000000000', '2010-01-20T00:00:00.000000000',
#        '2010-01-21T00:00:00.000000000', '2010-01-22T00:00:00.000000000',
#        '2010-01-23T00:00:00.000000000', '2010-01-24T00:00:00.000000000',
#        '2010-01-25T00:00:00.000000000', '2010-01-26T00:00:00.000000000',
#        '2010-01-27T00:00:00.000000000', '2010-01-28T00:00:00.000000000',
#        '2010-01-29T00:00:00.000000000', '2010-01-30T00:00:00.000000000',
#        '2010-01-31T00:00:00.000000000', '2010-02-01T00:00:00.000000000',
#        '2010-02-02T00:00:00.000000000', '2010-02-03T00:00:00.000000000',
#        '2010-02-04T00:00:00.000000000', '2010-02-05T00:00:00.000000000',
#        '2010-02-06T00:00:00.000000000', '2010-02-07T00:00:00.000000000',
#        '2010-02-08T00:00:00.000000000', '2010-02-09T00:00:00.000000000',
#        '2010-02-10T00:00:00.000000000', '2010-02-11T00:00:00.000000000',
#        '2010-02-12T00:00:00.000000000', '2010-02-13T00:00:00.000000000',
00:00:00.000000000'], dtype='datetime64[ns]')

# %%
df_from_xls["RANGO_HORARIO"].unique()
# Out:
# array(['DE 00:00 A 00:59', 'DE 1:00 A 1:59', 'DE 2:00 A 2:59',
#        'DE 4:00 A 4:59', 'DE 5:00 A 5:59', 'DE 8:00 A 8:59',
#        'DE 9:00 A 9:59', 'DE 20:00 A 20:59', 'DE 21:00 A 21:59',
#        'DE 6:00 A 6:59', 'DE 11:00 A 11:59', 'DE 12:00 A 12:59',
#        'DE 13:00 A 13:59', 'DE 14:00 A 14:59', 'DE 15:00 A 15:59',
#        'DE 18:00 A 18:59', 'DE 19:00 A 19:59', 'DE 22:00 A 22:59',
#        'DE 16:00 A 16:59', 'DE 17:00 A 17:59', 'DE 23:00 A 23:59',
#        'DE 7:00 A 7:59', 'DE 10:00 A 10:59', 'DE 3:00 A 3:59'],
#       dtype=object)

# %%
df_from_xls["DIA_SEMANA"].unique()
# Out:
# array(['VIERNES', 'SABADO', 'DOMINGO', 'LUNES', 'MARTES', 'MIERCOLES',
#        'JUEVES'], dtype=object)

# %%
df_from_xls["DISTRITO"].unique()
# Out:
# array(['CHAMARTIN', 'PUENTE DE VALLECAS', 'CHAMBERI', 'RETIRO',
#        'SALAMANCA', 'CARABANCHEL', 'CIUDAD LINEAL', 'MONCLOA-ARAVACA',
#        'TETUAN', 'VILLA DE VALLECAS', 'MORATALAZ', 'ARGANZUELA',
#        'SAN BLAS', 'VILLAVERDE', 'HORTALEZA', 'FUENCARRAL-EL PARDO',
#        'VICALVARO', 'USERA', 'LATINA', 'BARAJAS', 'CENTRO'], dtype=object)

# %%
df_from_xls["NUM_PERSONAS"].unique()
# Out:
# array([ 1,  7,  2,  3,  4,  5,  9,  6,  8, 18, 13])

# %%
df_from_xls["TIPO_ACCIDENTE"].unique()
# Out:
# array(['COLISIÓN DOBLE', 'COLISIÓN MÚLTIPLE', 'CHOQUE CON OBJETO FIJO',
#        'CAÍDA MOTOCICLETA', 'ATROPELLO', 'VUELCO', 'CAÍDA CICLOMOTOR',
#        'CAÍDA VIAJERO BUS', 'OTRAS CAUSAS', 'CAÍDA BICICLETA'],
#       dtype=object)

# %%
df_from_xls["TIPO_VEHICULO"].unique()
# Out:
# array(['TURISMO', 'NO ASIGNADO', 'FURGONETA', 'MOTOCICLETA', 'AUTO-TAXI',
#        'VARIOS', 'CAMION', 'CICLOMOTOR', 'AUTOBUS-AUTOCAR', 'BICICLETA',
#        'AMBULANCIA'], dtype=object)

# %%
df_from_xls["TIPO_PERSONA"].unique()
# Out:
# array(['CONDUCTOR', 'VIAJERO', 'TESTIGO', 'PEATON'], dtype=object)

# %%
df_from_xls["SEXO"].unique()
# Out:
# array(['HOMBRE', 'MUJER', 'NO ASIGNADO'], dtype=object)

# %%
df_from_xls["LESIVIDAD"].unique()
# Out:
# array(['IL', 'HL', 'HG', 'NO ASIGNADA', 'MT'], dtype=object)

# %%
df_from_xls["TRAMO_EDAD"].unique()
# Out:
# array(['DE 18 A 20 AÑOS', 'DE 50 A 54 AÑOS', 'DE 40 A 44 AÑOS',
#        'DE 25 A 29 AÑOS', 'DE 30 A 34 ANOS', 'DE 21 A 24 AÑOS',
#        'DE 35 A 39 AÑOS', 'DE 60 A 64 AÑOS', 'DE 45 A 49 AÑOS',
#        'DE 0 A 5 AÑOS', 'DESCONOCIDA', 'DE 70 A 74 AÑOS',
#        'DE MAS DE 74 AÑOS', 'DE 10 A 14 AÑOS', 'DE 6 A 9 AÑOS',
#        'DE 55 A 59 AÑOS', 'DE 65 A 69 AÑOS', 'DE 15 A 17 AÑOS'],
#       dtype=object)

# %%
df_from_xls.dtypes
# Out:
# FECHA             datetime64[ns]
# RANGO_HORARIO             object
# DIA_SEMANA                object
# DISTRITO                  object
# NUM_PERSONAS               int64
# TIPO_ACCIDENTE            object
# TIPO_VEHICULO             object
# TIPO_PERSONA              object
# SEXO                      object
# LESIVIDAD                 object
# TRAMO_EDAD                object
# dtype: object

# %%
df_from_xls["RANGO_HORARIO"][0]
# Out:
# 'DE 00:00 A 00:59'

# %%
df_from_xls['BORRAR'], df_from_xls['RESTO_RANGO_HORARIO'] = df_from_xls['RANGO_HORARIO'].str.split(' ', 1).str

# %%
df_from_xls.columns
# Out:
# Index(['FECHA', 'RANGO_HORARIO', 'DIA_SEMANA', 'DISTRITO', 'NUM_PERSONAS',
#        'TIPO_ACCIDENTE', 'TIPO_VEHICULO', 'TIPO_PERSONA', 'SEXO', 'LESIVIDAD',
#        'TRAMO_EDAD', 'BORRAR', 'RESTO_RANGO_HORARIO'],
#       dtype='object')

# %%
df_from_xls.head(1)
# Out:
#        FECHA     RANGO_HORARIO DIA_SEMANA   DISTRITO  NUM_PERSONAS  \
# 0 2010-01-01  DE 00:00 A 00:59    VIERNES  CHAMARTIN             1
#
#    TIPO_ACCIDENTE TIPO_VEHICULO TIPO_PERSONA    SEXO LESIVIDAD  \
# 0  COLISIÓN DOBLE       TURISMO    CONDUCTOR  HOMBRE        IL
#
#         TRAMO_EDAD BORRAR RESTO_RANGO_HORARIO
# 0  DE 18 A 20 AÑOS     DE       00:00 A 00:59

# %%
df_from_xls.tail(1)
# Out:
#            FECHA     RANGO_HORARIO DIA_SEMANA DISTRITO  NUM_PERSONAS  \
# 26577 2010-12-31  DE 23:00 A 23:59    VIERNES   RETIRO             1
#
#       TIPO_ACCIDENTE TIPO_VEHICULO TIPO_PERSONA    SEXO LESIVIDAD  \
# 26577      ATROPELLO       TURISMO      VIAJERO  HOMBRE        IL
#
#             TRAMO_EDAD BORRAR RESTO_RANGO_HORARIO
# 26577  DE 55 A 59 AÑOS     DE       23:00 A 23:59

# %%
# borrar columnas sobrantes:
del df_from_xls['BORRAR']

# %%
df_from_xls.head(1)
# Out:
#        FECHA     RANGO_HORARIO DIA_SEMANA   DISTRITO  NUM_PERSONAS  \
# 0 2010-01-01  DE 00:00 A 00:59    VIERNES  CHAMARTIN             1
#
#    TIPO_ACCIDENTE TIPO_VEHICULO TIPO_PERSONA    SEXO LESIVIDAD  \
# 0  COLISIÓN DOBLE       TURISMO    CONDUCTOR  HOMBRE        IL
#
#         TRAMO_EDAD RESTO_RANGO_HORARIO
# 0  DE 18 A 20 AÑOS       00:00 A 00:59

# %%
df_from_xls['HORA'], df_from_xls['BORRAR'] = df_from_xls['RESTO_RANGO_HORARIO'].str.split(' ', 1).str

# %%
df_from_xls.head(1)
# Out:
#        FECHA     RANGO_HORARIO DIA_SEMANA   DISTRITO  NUM_PERSONAS  \
# 0 2010-01-01  DE 00:00 A 00:59    VIERNES  CHAMARTIN             1
#
#    TIPO_ACCIDENTE TIPO_VEHICULO TIPO_PERSONA    SEXO LESIVIDAD  \
# 0  COLISIÓN DOBLE       TURISMO    CONDUCTOR  HOMBRE        IL
#
#         TRAMO_EDAD RESTO_RANGO_HORARIO   HORA   BORRAR
# 0  DE 18 A 20 AÑOS       00:00 A 00:59  00:00  A 00:59

# %%
# borrar columnas sobrantes:
df_from_xls = df_from_xls.drop(["RANGO_HORARIO","RESTO_RANGO_HORARIO","BORRAR"], axis=1)

# %%
df_from_xls.head(1)
# Out:
#        FECHA DIA_SEMANA   DISTRITO  NUM_PERSONAS  TIPO_ACCIDENTE  \
# 0 2010-01-01    VIERNES  CHAMARTIN             1  COLISIÓN DOBLE
#
#   TIPO_VEHICULO TIPO_PERSONA    SEXO LESIVIDAD       TRAMO_EDAD   HORA
# 0       TURISMO    CONDUCTOR  HOMBRE        IL  DE 18 A 20 AÑOS  00:00

# %%
df_from_xls.columns
# Out:
# Index(['FECHA', 'DIA_SEMANA', 'DISTRITO', 'NUM_PERSONAS', 'TIPO_ACCIDENTE',
#        'TIPO_VEHICULO', 'TIPO_PERSONA', 'SEXO', 'LESIVIDAD', 'TRAMO_EDAD',
#        'HORA'],
#       dtype='object')

# %%
# Contar observaciones
df_from_xls.count()
# Out:
# FECHA             26578
# DIA_SEMANA        26578
# DISTRITO          26578
# NUM_PERSONAS      26578
# TIPO_ACCIDENTE    26578
# TIPO_VEHICULO     26578
# TIPO_PERSONA      26578
# SEXO              26578
# LESIVIDAD         26578
# TRAMO_EDAD        26578
# HORA              26578
# dtype: int64

# %%
df_from_xls["HORA"][0]
# Out:
# '00:00'

# %%
df_from_xls.columns
# Out:
# Index(['FECHA', 'DIA_SEMANA', 'DISTRITO', 'NUM_PERSONAS', 'TIPO_ACCIDENTE',
#        'TIPO_VEHICULO', 'TIPO_PERSONA', 'SEXO', 'LESIVIDAD', 'TRAMO_EDAD',
#        'HORA'],
#       dtype='object')

# %%
ordenar_columnas = df_from_xls.columns.tolist()
ordenar_columnas
# Out:
# ['FECHA',
#  'DIA_SEMANA',
#  'DISTRITO',
#  'NUM_PERSONAS',
#  'TIPO_ACCIDENTE',
#  'TIPO_VEHICULO',
#  'TIPO_PERSONA',
#  'SEXO',
#  'LESIVIDAD',
#  'TRAMO_EDAD',
#  'HORA']

# %%
ordenar_columnas = ordenar_columnas[0:1] + ordenar_columnas[-1:] + ordenar_columnas[1:-1]
ordenar_columnas
# Out:
# ['FECHA',
#  'HORA',
#  'DIA_SEMANA',
#  'DISTRITO',
#  'NUM_PERSONAS',
#  'TIPO_ACCIDENTE',
#  'TIPO_VEHICULO',
#  'TIPO_PERSONA',
#  'SEXO',
#  'LESIVIDAD',
#  'TRAMO_EDAD']

# %%
df_from_xls = df_from_xls[ordenar_columnas]
df_from_xls
# Out:
#            FECHA   HORA DIA_SEMANA             DISTRITO  NUM_PERSONAS  \
# 0     2010-01-01  00:00    VIERNES            CHAMARTIN             1
# 1     2010-01-01  00:00    VIERNES            CHAMARTIN             1
# 2     2010-01-01  00:00    VIERNES            CHAMARTIN             1
# 3     2010-01-01   1:00    VIERNES   PUENTE DE VALLECAS             7
# 4     2010-01-01   1:00    VIERNES   PUENTE DE VALLECAS             7
# 5     2010-01-01   1:00    VIERNES   PUENTE DE VALLECAS             7
# 6     2010-01-01   1:00    VIERNES   PUENTE DE VALLECAS             7
# 7     2010-01-01   1:00    VIERNES   PUENTE DE VALLECAS             7
# 8     2010-01-01   1:00    VIERNES   PUENTE DE VALLECAS             7
# 9     2010-01-01   1:00    VIERNES   PUENTE DE VALLECAS             7
# 10    2010-01-01   1:00    VIERNES   PUENTE DE VALLECAS             7
# 11    2010-01-01   2:00    VIERNES             CHAMBERI             1
# 12    2010-01-01   2:00    VIERNES             CHAMBERI             1
# 13    2010-01-01   4:00    VIERNES               RETIRO             7
# 14    2010-01-01   4:00    VIERNES               RETIRO             7
# 15    2010-01-01   4:00    VIERNES               RETIRO             7
# 16    2010-01-01   4:00    VIERNES               RETIRO             7
# 17    2010-01-01   4:00    VIERNES               RETIRO             7
# 18    2010-01-01   4:00    VIERNES               RETIRO             7
# 11             COLISIÓN DOBLE   MOTOCICLETA    CONDUCTOR  HOMBRE        HL
# 12             COLISIÓN DOBLE     AUTO-TAXI    CONDUCTOR  HOMBRE        IL
# 13          COLISIÓN MÚLTIPLE   NO ASIGNADO      TESTIGO  HOMBRE        IL
# 14          COLISIÓN MÚLTIPLE   NO ASIGNADO      TESTIGO  HOMBRE        IL
# 15          COLISIÓN MÚLTIPLE       TURISMO    CONDUCTOR  HOMBRE        HL
# 16          COLISIÓN MÚLTIPLE       TURISMO      VIAJERO  HOMBRE        IL
# 17          COLISIÓN MÚLTIPLE       TURISMO      VIAJERO   MUJER        IL
# 18          COLISIÓN MÚLTIPLE       TURISMO      VIAJERO   MUJER        HG
# 19          COLISIÓN MÚLTIPLE       TURISMO      VIAJERO   MUJER        HL
# 20          COLISIÓN MÚLTIPLE   MOTOCICLETA    CONDUCTOR  HOMBRE        HL
# 21          COLISIÓN MÚLTIPLE        VARIOS    CONDUCTOR  HOMBRE        HL
# 22          COLISIÓN MÚLTIPLE        VARIOS      VIAJERO   MUJER        HL
# 23          COLISIÓN MÚLTIPLE        VARIOS      VIAJERO  HOMBRE        HL
# 24             COLISIÓN DOBLE       TURISMO    CONDUCTOR  HOMBRE        HL
# 25             COLISIÓN DOBLE       TURISMO    CONDUCTOR   MUJER        IL
# 26             COLISIÓN DOBLE       TURISMO      VIAJERO  HOMBRE        IL
# 27     CHOQUE CON OBJETO FIJO       TURISMO    CONDUCTOR  HOMBRE        HL
# 28     CHOQUE CON OBJETO FIJO       TURISMO      VIAJERO  HOMBRE        HL
# 29          CAÍDA MOTOCICLETA   MOTOCICLETA    CONDUCTOR  HOMBRE        HL
# ...                       ...           ...          ...     ...       ...
# 26548          COLISIÓN DOBLE       TURISMO    CONDUCTOR  HOMBRE        IL
# 26549          COLISIÓN DOBLE       TURISMO      VIAJERO   MUJER        IL
# 26550          COLISIÓN DOBLE    CICLOMOTOR    CONDUCTOR  HOMBRE        HG
# 26551               ATROPELLO   NO ASIGNADO       PEATON  HOMBRE        HL
# 26552               ATROPELLO       TURISMO    CONDUCTOR   MUJER        IL
# 26553               ATROPELLO       TURISMO    CONDUCTOR  HOMBRE        IL
# 26554               ATROPELLO   NO ASIGNADO       PEATON  HOMBRE        HL
# 26555               ATROPELLO       TURISMO    CONDUCTOR   MUJER        IL
# 26556               ATROPELLO       TURISMO      VIAJERO   MUJER        IL
# 26557          COLISIÓN DOBLE       TURISMO    CONDUCTOR  HOMBRE        IL
# 26558          COLISIÓN DOBLE       TURISMO    CONDUCTOR  HOMBRE        HL
# 26559       COLISIÓN MÚLTIPLE       TURISMO    CONDUCTOR  HOMBRE        IL
# 26560       COLISIÓN MÚLTIPLE       TURISMO    CONDUCTOR  HOMBRE        IL
# 26561       COLISIÓN MÚLTIPLE       TURISMO    CONDUCTOR  HOMBRE        HL
# 26562       COLISIÓN MÚLTIPLE       TURISMO      VIAJERO  HOMBRE        HL
# 26563       COLISIÓN MÚLTIPLE       TURISMO      VIAJERO  HOMBRE        HL
# 26564          COLISIÓN DOBLE   NO ASIGNADO      TESTIGO  HOMBRE        IL
# 26565          COLISIÓN DOBLE       TURISMO    CONDUCTOR   MUJER        IL
# 26566          COLISIÓN DOBLE   MOTOCICLETA    CONDUCTOR  HOMBRE        HL
# 26567        CAÍDA CICLOMOTOR    CICLOMOTOR    CONDUCTOR   MUJER        HL
# 26568  CHOQUE CON OBJETO FIJO   NO ASIGNADO      TESTIGO  HOMBRE        IL
# 26569  CHOQUE CON OBJETO FIJO       TURISMO    CONDUCTOR  HOMBRE        HL
# 26570               ATROPELLO   NO ASIGNADO       PEATON   MUJER        HL
# 26571               ATROPELLO   NO ASIGNADO      TESTIGO  HOMBRE        IL
# 26572               ATROPELLO       TURISMO    CONDUCTOR  HOMBRE        IL
# 26573       CAÍDA MOTOCICLETA   MOTOCICLETA    CONDUCTOR  HOMBRE        HL
# 26574  CHOQUE CON OBJETO FIJO   MOTOCICLETA    CONDUCTOR  HOMBRE        HL
# 26575               ATROPELLO   NO ASIGNADO       PEATON  HOMBRE        HL
# 26576               ATROPELLO       TURISMO    CONDUCTOR   MUJER        IL
# 26577               ATROPELLO       TURISMO      VIAJERO  HOMBRE        IL
#
#               TRAMO_EDAD
# 0        DE 18 A 20 AÑOS
# 1        DE 50 A 54 AÑOS
# 2        DE 40 A 44 AÑOS
# 3        DE 25 A 29 AÑOS
# 4        DE 30 A 34 ANOS
# 5        DE 25 A 29 AÑOS
# 6        DE 25 A 29 AÑOS
# 7        DE 25 A 29 AÑOS
# 8        DE 25 A 29 AÑOS
# 9        DE 21 A 24 AÑOS
# 10       DE 25 A 29 AÑOS
# 11       DE 35 A 39 AÑOS
# 12       DE 35 A 39 AÑOS
# 13       DE 25 A 29 AÑOS
# 14       DE 30 A 34 ANOS
# 15       DE 25 A 29 AÑOS
# 16       DE 30 A 34 ANOS
# 17       DE 18 A 20 AÑOS
# 18       DE 21 A 24 AÑOS
# 19       DE 21 A 24 AÑOS
# 20       DE 30 A 34 ANOS
# 21       DE 18 A 20 AÑOS
# 22       DE 21 A 24 AÑOS
# 23       DE 18 A 20 AÑOS
# 24       DE 60 A 64 AÑOS
# 25       DE 25 A 29 AÑOS
# 26       DE 25 A 29 AÑOS
# 27       DE 35 A 39 AÑOS
# 28       DE 45 A 49 AÑOS
# 29       DE 30 A 34 ANOS
# ...                  ...
# 26548    DE 35 A 39 AÑOS
# 26549    DE 30 A 34 ANOS
# 26550    DE 25 A 29 AÑOS
# 26551    DE 18 A 20 AÑOS
# 26552    DE 25 A 29 AÑOS
# 26553    DE 21 A 24 AÑOS
# 26554    DE 60 A 64 AÑOS
# 26555    DE 21 A 24 AÑOS
# 26556  DE MAS DE 74 AÑOS
# 26557    DE 21 A 24 AÑOS
# 26558    DE 30 A 34 ANOS
# 26559      DE 0 A 5 AÑOS
# 26560    DE 35 A 39 AÑOS
# 26561    DE 25 A 29 AÑOS
# 26562      DE 0 A 5 AÑOS
# 26563    DE 21 A 24 AÑOS
# 26564    DE 18 A 20 AÑOS
# 26565    DE 50 A 54 AÑOS
# 26566    DE 35 A 39 AÑOS
# 26567    DE 40 A 44 AÑOS
# 26568    DE 25 A 29 AÑOS
# 26569    DE 25 A 29 AÑOS
# 26570    DE 30 A 34 ANOS
# 26571    DE 30 A 34 ANOS
# 26572    DE 18 A 20 AÑOS
# 26573    DE 45 A 49 AÑOS
# 26574    DE 30 A 34 ANOS
# 26575    DE 40 A 44 AÑOS
# 26576    DE 25 A 29 AÑOS
# 26577    DE 55 A 59 AÑOS
#
# [26578 rows x 11 columns]

# %%
df_from_xls["FECHA"][0]
# Out:
# Timestamp('2010-01-01 00:00:00')

# %%
df_from_xls["FECHA"][26577]
# Out:
# Timestamp('2010-12-31 00:00:00')

# %%
df_from_xls["FECHA"] = df_from_xls["FECHA"].dt.strftime('%d/%m/%Y')

# %%
df_from_xls["FECHA"][0]
# Out:
# '01/01/2010'

# %%
type(df_from_xls["FECHA"])
# Out:
# pandas.core.series.Series

# %%
df_from_xls.head(1)
# Out:
#         FECHA   HORA DIA_SEMANA   DISTRITO  NUM_PERSONAS  TIPO_ACCIDENTE  \
# 0  01/01/2010  00:00    VIERNES  CHAMARTIN             1  COLISIÓN DOBLE
#
#   TIPO_VEHICULO TIPO_PERSONA    SEXO LESIVIDAD       TRAMO_EDAD
# 0       TURISMO    CONDUCTOR  HOMBRE        IL  DE 18 A 20 AÑOS

# %%
df_from_xls.dtypes
# Out:
# FECHA             object
# HORA              object
# DIA_SEMANA        object
# DISTRITO          object
# NUM_PERSONAS       int64
# TIPO_ACCIDENTE    object
# TIPO_VEHICULO     object
# TIPO_PERSONA      object
# SEXO              object
# LESIVIDAD         object
# TRAMO_EDAD        object
# dtype: object

# %%
df_from_xls["TRAMO_EDAD"].unique()
# Out:
# array(['DE 18 A 20 AÑOS', 'DE 50 A 54 AÑOS', 'DE 40 A 44 AÑOS',
#        'DE 25 A 29 AÑOS', 'DE 30 A 34 ANOS', 'DE 21 A 24 AÑOS',
#        'DE 35 A 39 AÑOS', 'DE 60 A 64 AÑOS', 'DE 45 A 49 AÑOS',
#        'DE 0 A 5 AÑOS', 'DESCONOCIDA', 'DE 70 A 74 AÑOS',
#        'DE MAS DE 74 AÑOS', 'DE 10 A 14 AÑOS', 'DE 6 A 9 AÑOS',
#        'DE 55 A 59 AÑOS', 'DE 65 A 69 AÑOS', 'DE 15 A 17 AÑOS'],
#       dtype=object)

# %%
df_from_xls['BORRAR'], df_from_xls['EDAD'] = df_from_xls['TRAMO_EDAD'].str.split(' ', 1).str

# %%
df_from_xls.columns
# Out:
# Index(['FECHA', 'HORA', 'DIA_SEMANA', 'DISTRITO', 'NUM_PERSONAS',
#        'TIPO_ACCIDENTE', 'TIPO_VEHICULO', 'TIPO_PERSONA', 'SEXO', 'LESIVIDAD',
#        'TRAMO_EDAD', 'BORRAR', 'EDAD'],
#       dtype='object')

# %%
df_from_xls["EDAD"].unique()
# Out:
# array(['18 A 20 AÑOS', '50 A 54 AÑOS', '40 A 44 AÑOS', '25 A 29 AÑOS',
#        '30 A 34 ANOS', '21 A 24 AÑOS', '35 A 39 AÑOS', '60 A 64 AÑOS',
#        '45 A 49 AÑOS', '0 A 5 AÑOS', nan, '70 A 74 AÑOS',
#        'MAS DE 74 AÑOS', '10 A 14 AÑOS', '6 A 9 AÑOS', '55 A 59 AÑOS',
#        '65 A 69 AÑOS', '15 A 17 AÑOS'], dtype=object)

# %%
# Comprobar valores nulos
df_from_xls.isnull().sum()
# Out:
# FECHA                0
# HORA                 0
# DIA_SEMANA           0
# DISTRITO             0
# NUM_PERSONAS         0
# TIPO_ACCIDENTE       0
# TIPO_VEHICULO        0
# TIPO_PERSONA         0
# SEXO                 0
# LESIVIDAD            0
# TRAMO_EDAD           0
# BORRAR               0
# EDAD              2344
# dtype: int64

# %%
# borrar columnas sobrantes:
del df_from_xls['BORRAR']
del df_from_xls['TRAMO_EDAD']

# %%
df_from_xls['TRAMO_EDAD'], df_from_xls['BORRAR'] = df_from_xls['EDAD'].str.split(' ', 1).str

# %%
df_from_xls.columns
# Out:
# Index(['FECHA', 'HORA', 'DIA_SEMANA', 'DISTRITO', 'NUM_PERSONAS',
#        'TIPO_ACCIDENTE', 'TIPO_VEHICULO', 'TIPO_PERSONA', 'SEXO', 'LESIVIDAD',
#        'EDAD', 'TRAMO_EDAD', 'BORRAR'],
#       dtype='object')

# %%
df_from_xls["TRAMO_EDAD"].unique()
# Out:
# array(['18', '50', '40', '25', '30', '21', '35', '60', '45', '0', nan,
#        '70', 'MAS', '10', '6', '55', '65', '15'], dtype=object)

# %%
# Comprobar valores nulos
df_from_xls.isnull().sum()
# Out:
# FECHA                0
# HORA                 0
# DIA_SEMANA           0
# DISTRITO             0
# NUM_PERSONAS         0
# TIPO_ACCIDENTE       0
# TIPO_VEHICULO        0
# TIPO_PERSONA         0
# SEXO                 0
# LESIVIDAD            0
# EDAD              2344
# TRAMO_EDAD        2344
# BORRAR            2344
# dtype: int64

# %%
# borrar columnas sobrantes:
del df_from_xls['EDAD']
del df_from_xls['BORRAR']

# %%
# Comprobar valores nulos
df_from_xls.isnull().sum()
# Out:
# FECHA                0
# HORA                 0
# DIA_SEMANA           0
# DISTRITO             0
# NUM_PERSONAS         0
# TIPO_ACCIDENTE       0
# TIPO_VEHICULO        0
# TIPO_PERSONA         0
# SEXO                 0
# LESIVIDAD            0
# TRAMO_EDAD        2344
# dtype: int64

# %%
df_from_xls["TRAMO_EDAD"].unique()
# Out:
# array(['18', '50', '40', '25', '30', '21', '35', '60', '45', '0', nan,
#        '70', 'MAS', '10', '6', '55', '65', '15'], dtype=object)

# %%
df_from_xls["TRAMO_EDAD"] = df_from_xls["TRAMO_EDAD"].replace({"MAS":74}, regex=True)

# %%
df_from_xls["TRAMO_EDAD"].unique()
# Out:
# array(['18', '50', '40', '25', '30', '21', '35', '60', '45', '0', nan,
#        '70', 74, '10', '6', '55', '65', '15'], dtype=object)

# %%
df_from_xls["TRAMO_EDAD"].fillna("NO_ASIGNADO", inplace=True)

# %%
df_from_xls["TRAMO_EDAD"].unique()
# Out:
# array(['18', '50', '40', '25', '30', '21', '35', '60', '45', '0',
#        'NO_ASIGNADO', '70', 74, '10', '6', '55', '65', '15'], dtype=object)

# %%
# Comprobar valores nulos
df_from_xls.isnull().sum()
# Out:
# FECHA             0
# HORA              0
# DIA_SEMANA        0
# DISTRITO          0
# NUM_PERSONAS      0
# TIPO_ACCIDENTE    0
# TIPO_VEHICULO     0
# TIPO_PERSONA      0
# SEXO              0
# LESIVIDAD         0
# TRAMO_EDAD        0
# dtype: int64

# %%
df_from_xls.shape
# Out:
# (26578, 11)

# %%
df_from_xls.duplicated().sum()
# Out:
# 877

# %%
df_from_xls["DIA_SEMANA"].unique()
# Out:
# array(['VIERNES', 'SABADO', 'DOMINGO', 'LUNES', 'MARTES', 'MIERCOLES',
#        'JUEVES'], dtype=object)

# %%
df_from_xls["DIA_SEMANA"].fillna("NO_ASIGNADO", inplace=True)

# %%
df_from_xls["DISTRITO"].unique()
# Out:
# array(['CHAMARTIN', 'PUENTE DE VALLECAS', 'CHAMBERI', 'RETIRO',
#        'SALAMANCA', 'CARABANCHEL', 'CIUDAD LINEAL', 'MONCLOA-ARAVACA',
#        'TETUAN', 'VILLA DE VALLECAS', 'MORATALAZ', 'ARGANZUELA',
#        'SAN BLAS', 'VILLAVERDE', 'HORTALEZA', 'FUENCARRAL-EL PARDO',
#        'VICALVARO', 'USERA', 'LATINA', 'BARAJAS', 'CENTRO'], dtype=object)

# %%
df_from_xls["DISTRITO"].fillna("NO_ASIGNADO", inplace=True)

# %%
df_from_xls["NUM_PERSONAS"].unique()
# Out:
# array([ 1,  7,  2,  3,  4,  5,  9,  6,  8, 18, 13])

# %%
df_from_xls["NUM_PERSONAS"].fillna("NO_ASIGNADO", inplace=True)

# %%
df_from_xls["TIPO_ACCIDENTE"].unique()
# Out:
# array(['COLISIÓN DOBLE', 'COLISIÓN MÚLTIPLE', 'CHOQUE CON OBJETO FIJO',
#        'CAÍDA MOTOCICLETA', 'ATROPELLO', 'VUELCO', 'CAÍDA CICLOMOTOR',
#        'CAÍDA VIAJERO BUS', 'OTRAS CAUSAS', 'CAÍDA BICICLETA'],
#       dtype=object)

# %%
df_from_xls["TIPO_ACCIDENTE"].fillna("NO_ASIGNADO", inplace=True)

# %%
df_from_xls["TIPO_VEHICULO"].unique()
# Out:
# array(['TURISMO', 'NO ASIGNADO', 'FURGONETA', 'MOTOCICLETA', 'AUTO-TAXI',
#        'VARIOS', 'CAMION', 'CICLOMOTOR', 'AUTOBUS-AUTOCAR', 'BICICLETA',
#        'AMBULANCIA'], dtype=object)

# %%
df_from_xls["TIPO_VEHICULO"].fillna("NO_ASIGNADO", inplace=True)

# %%
df_from_xls["TIPO_PERSONA"].unique()
# Out:
# array(['CONDUCTOR', 'VIAJERO', 'TESTIGO', 'PEATON'], dtype=object)

# %%
df_from_xls["TIPO_PERSONA"].fillna("NO_ASIGNADO", inplace=True)

# %%
df_from_xls["SEXO"].unique()
# Out:
# array(['HOMBRE', 'MUJER', 'NO ASIGNADO'], dtype=object)

# %%
df_from_xls["SEXO"].fillna("NO ASIGNADO", inplace=True)

# %%
df_from_xls["LESIVIDAD"].unique()
# Out:
# array(['IL', 'HL', 'HG', 'NO ASIGNADA', 'MT'], dtype=object)

# %%
df_from_xls["LESIVIDAD"].fillna("NO ASIGNADO", inplace=True)

# %%
df_from_xls["HORA"].unique()
# Out:
# array(['00:00', '1:00', '2:00', '4:00', '5:00', '8:00', '9:00', '20:00',
#        '21:00', '6:00', '11:00', '12:00', '13:00', '14:00', '15:00',
#        '18:00', '19:00', '22:00', '16:00', '17:00', '23:00', '7:00',
#        '10:00', '3:00'], dtype=object)

# %%
df_from_xls["HORA"].fillna("NO_ASIGNADO", inplace=True)

# %%
df_from_xls["TRAMO_EDAD"].unique()
# Out:
# array(['18', '50', '40', '25', '30', '21', '35', '60', '45', '0',
#        'NO_ASIGNADO', '70', 74, '10', '6', '55', '65', '15'], dtype=object)

# %%
df_from_xls["TRAMO_EDAD"].fillna("NO_ASIGNADO", inplace=True)

# %%
df_from_xls.head()
# Out:
#         FECHA   HORA DIA_SEMANA            DISTRITO  NUM_PERSONAS  \
# 0  01/01/2010  00:00    VIERNES           CHAMARTIN             1
# 1  01/01/2010  00:00    VIERNES           CHAMARTIN             1
# 2  01/01/2010  00:00    VIERNES           CHAMARTIN             1
# 3  01/01/2010   1:00    VIERNES  PUENTE DE VALLECAS             7
# 4  01/01/2010   1:00    VIERNES  PUENTE DE VALLECAS             7
#
#       TIPO_ACCIDENTE TIPO_VEHICULO TIPO_PERSONA    SEXO LESIVIDAD TRAMO_EDAD
# 0     COLISIÓN DOBLE       TURISMO    CONDUCTOR  HOMBRE        IL         18
# 1     COLISIÓN DOBLE       TURISMO    CONDUCTOR  HOMBRE        IL         50
# 2     COLISIÓN DOBLE       TURISMO      VIAJERO   MUJER        HL         40
# 3  COLISIÓN MÚLTIPLE   NO ASIGNADO      VIAJERO   MUJER        HL         25
# 4  COLISIÓN MÚLTIPLE   NO ASIGNADO      VIAJERO   MUJER        HL         30

# %%
df_from_xls.columns
# Out:
# Index(['FECHA', 'HORA', 'DIA_SEMANA', 'DISTRITO', 'NUM_PERSONAS',
#        'TIPO_ACCIDENTE', 'TIPO_VEHICULO', 'TIPO_PERSONA', 'SEXO', 'LESIVIDAD',
#        'TRAMO_EDAD'],
#       dtype='object')

# %%
df_from_xls["HORA"][3]
# Out:
# '1:00'

# %%
df_from_xls["HORA"] = pd.to_datetime(df_from_xls["HORA"],errors="coerce").dt.strftime("%H:%M")
print (df_from_xls["HORA"][0])
# Out:
# 00:00

# %%
df_from_xls.HORA.dtype
# Out:
# dtype('O')

# %%
df_from_xls.dtypes
# Out:
# FECHA             object
# HORA              object
# DIA_SEMANA        object
# DISTRITO          object
# NUM_PERSONAS       int64
# TIPO_ACCIDENTE    object
# TIPO_VEHICULO     object
# TIPO_PERSONA      object
# SEXO              object
# LESIVIDAD         object
# TRAMO_EDAD        object
# dtype: object

# %%
df_from_xls.head(1)
# Out:
#         FECHA   HORA DIA_SEMANA   DISTRITO  NUM_PERSONAS  TIPO_ACCIDENTE  \
# 0  01/01/2010  00:00    VIERNES  CHAMARTIN             1  COLISIÓN DOBLE
#
#   TIPO_VEHICULO TIPO_PERSONA    SEXO LESIVIDAD TRAMO_EDAD
# 0       TURISMO    CONDUCTOR  HOMBRE        IL         18

# %%
df_from_xls.TRAMO_EDAD.head()
# Out:
# 0    18
# 1    50
# 2    40
# 3    25
# 4    30
# Name: TRAMO_EDAD, dtype: object

# %%
df_from_xls["TRAMO_EDAD"].unique()
# Out:
# array(['18', '50', '40', '25', '30', '21', '35', '60', '45', '0',
#        'NO_ASIGNADO', '70', 74, '10', '6', '55', '65', '15'], dtype=object)

# %%
df_from_xls.count()
# Out:
# FECHA             26578
# HORA              26578
# DIA_SEMANA        26578
# DISTRITO          26578
# NUM_PERSONAS      26578
# TIPO_ACCIDENTE    26578
# TIPO_VEHICULO     26578
# TIPO_PERSONA      26578
# SEXO              26578
# LESIVIDAD         26578
# TRAMO_EDAD        26578
# dtype: int64

# %%
#?pd.value_counts

# %%
pd.value_counts(df_from_xls['TRAMO_EDAD']=='NO_ASIGNADO', sort=True, ascending=False, normalize=False, bins=None, dropna=False)
# Out:
# False    24234
# True      2344
# Name: TRAMO_EDAD, dtype: int64

# %%
#import pandas as pd
df_from_xls["TRAMO_EDAD"] = df_from_xls["TRAMO_EDAD"].replace({"NO_ASIGNADO":999}, regex=True)

# %%
pd.value_counts(df_from_xls['TRAMO_EDAD']=='NO_ASIGNADO', sort=True, ascending=False, normalize=False, bins=None, dropna=False)
# Out:
# False    26578
# Name: TRAMO_EDAD, dtype: int64

# %%
df_from_xls["TRAMO_EDAD"] = pd.to_numeric(df_from_xls["TRAMO_EDAD"])

# %%
df_from_xls.TRAMO_EDAD.dtype
# Out:
# dtype('int64')

# %%
#df.loc[df.column_name condition, 'new column name'] = 'value if condition is met'
#df['new column name'] = df['df column_name'].apply(lambda x: 'value if condition is met' if x condition else 'value if condition is not met')
#df_from_xls.loc[(df_from_xls.TRAMO_EDAD >= 0) & (df_from_xls.TRAMO_EDAD < 10), 5] = 'Mis-Match'  

df_from_xls['EDAD_APROX'] = df_from_xls['TRAMO_EDAD'].apply\
(lambda x : 0 if x <= 0 else (5 if x <= 5 else (10 if x <= 10 else (15 if x <= 15 else \
(20 if x <= 20 else (25 if x <= 25 else (30 if x <= 30 else (35 if x <= 35 else \
(40 if x <= 40 else (45 if x <= 45 else (50 if x <= 50 else (55 if x <= 55 else \
(60 if x <= 50 else (65 if x <= 65 else (70 if x <= 70 else (75 if x <= 75 else \
(80 if x <= 80 else (85 if x <= 85 else (90 if x <= 90 else (95 if x <= 95 else \
(100 if x <= 100 else (105 if x <= 105 else (110 if x <= 110 else (115 if x <= 115 else \
(120 if x <= 120 else (125 if x <= 125 else 'NO_ASIGNADO'))))))))))))))))))))))))))

df_from_xls['EDAD_APROX']
# Out:
# 0        20
# 1        50
# 2        40
# 3        25
# 4        30
# 5        25
# 6        25
# 7        25
# 8        25
# 9        25
# 10       25
# 11       35
# 12       35
# 13       25
# 14       30
# 15       25
# 16       30
# 17       20
# 18       25
# 19       25
# 20       30
# 21       20
# 22       25
# 23       20
# 24       65
# 25       25
# 26       25
# 27       35
# 28       45
# 29       30
#          ..
# 26548    35
# 26549    30
# 26550    25
# 26551    20
# 26552    25
# 26553    25
# 26554    65
# 26555    25
# 26556    75
# 26557    25
# 26558    30
# 26559     0
# 26560    35
# 26561    25
# 26562     0
# 26563    25
# 26564    20
# 26565    50
# 26566    35
# 26567    40
# 26568    25
# 26569    25
# 26570    30
# 26571    30
# 26572    20
# 26573    45
# 26574    30
# 26575    40
# 26576    25
# 26577    55
# Name: EDAD_APROX, Length: 26578, dtype: object

# %%
df_from_xls.EDAD_APROX.dtype
# Out:
# dtype('O')

# %%
pd.value_counts(df_from_xls['EDAD_APROX']=='NO_ASIGNADO', sort=True, ascending=False, normalize=False, bins=None, dropna=False)
# Out:
# False    24234
# True      2344
# Name: EDAD_APROX, dtype: int64

# %%
# borrar columnas sobrantes:
#data_xls_sin_columnas = 
del df_from_xls['TRAMO_EDAD']
# data_xls_sin_columnas = data_xls.drop(['BORRAR', 'BORRAR', 'BORRAR', 'BORRAR', 'BORRAR', 'BORRAR', 'BORRAR', 'BORRAR', 'BORRAR', 'BORRAR', 'BORRAR', 'BORRAR', 'BORRAR', 'BORRAR'], axis='columns', inplace=True)

# %%
df_from_xls.columns
# Out:
# Index(['FECHA', 'HORA', 'DIA_SEMANA', 'DISTRITO', 'NUM_PERSONAS',
#        'TIPO_ACCIDENTE', 'TIPO_VEHICULO', 'TIPO_PERSONA', 'SEXO', 'LESIVIDAD',
#        'EDAD_APROX'],
#       dtype='object')

# %%
df_from_xls.dtypes
# Out:
# FECHA             object
# HORA              object
# DIA_SEMANA        object
# DISTRITO          object
# NUM_PERSONAS       int64
# TIPO_ACCIDENTE    object
# TIPO_VEHICULO     object
# TIPO_PERSONA      object
# SEXO              object
# LESIVIDAD         object
# EDAD_APROX        object
# dtype: object

# %%
df_from_xls.head(1)
# Out:
#         FECHA   HORA DIA_SEMANA   DISTRITO  NUM_PERSONAS  TIPO_ACCIDENTE  \
# 0  01/01/2010  00:00    VIERNES  CHAMARTIN             1  COLISIÓN DOBLE
#
#   TIPO_VEHICULO TIPO_PERSONA    SEXO LESIVIDAD EDAD_APROX
# 0       TURISMO    CONDUCTOR  HOMBRE        IL         20

# %%
df_from_xls["LESIVIDAD"].unique()
# Out:
# array(['IL', 'HL', 'HG', 'NO ASIGNADA', 'MT'], dtype=object)

# %%
df_from_xls["LESIVIDAD"] = df_from_xls["LESIVIDAD"].replace({"IL":'INGRESO_LEVE'}, regex=True)
df_from_xls["LESIVIDAD"] = df_from_xls["LESIVIDAD"].replace({"HL":'HERIDO_LEVE'}, regex=True)
df_from_xls["LESIVIDAD"] = df_from_xls["LESIVIDAD"].replace({"HG":'HERIDO_GRAVE'}, regex=True)
df_from_xls["LESIVIDAD"] = df_from_xls["LESIVIDAD"].replace({"NO ASIGNADA":'NO_ASIGNADO'}, regex=True)
df_from_xls["LESIVIDAD"] = df_from_xls["LESIVIDAD"].replace({"MT":'MUERTO'}, regex=True)

# %%
df_from_xls["LESIVIDAD"].unique()
# Out:
# array(['INGRESO_LEVE', 'HERIDO_LEVE', 'HERIDO_GRAVE', 'NO_ASIGNADO',
#        'MUERTO'], dtype=object)

# %%
df_from_xls.head()
# Out:
#         FECHA   HORA DIA_SEMANA            DISTRITO  NUM_PERSONAS  \
# 0  01/01/2010  00:00    VIERNES           CHAMARTIN             1
# 1  01/01/2010  00:00    VIERNES           CHAMARTIN             1
# 2  01/01/2010  00:00    VIERNES           CHAMARTIN             1
# 3  01/01/2010  01:00    VIERNES  PUENTE DE VALLECAS             7
# 4  01/01/2010  01:00    VIERNES  PUENTE DE VALLECAS             7
#
#       TIPO_ACCIDENTE TIPO_VEHICULO TIPO_PERSONA    SEXO     LESIVIDAD  \
# 0     COLISIÓN DOBLE       TURISMO    CONDUCTOR  HOMBRE  INGRESO_LEVE
# 1     COLISIÓN DOBLE       TURISMO    CONDUCTOR  HOMBRE  INGRESO_LEVE
# 2     COLISIÓN DOBLE       TURISMO      VIAJERO   MUJER   HERIDO_LEVE
# 3  COLISIÓN MÚLTIPLE   NO ASIGNADO      VIAJERO   MUJER   HERIDO_LEVE
# 4  COLISIÓN MÚLTIPLE   NO ASIGNADO      VIAJERO   MUJER   HERIDO_LEVE
#
#   EDAD_APROX
# 0         20
# 1         50
# 2         40
# 3         25
# 4         30

# %%
df_from_xls["SEXO"].unique()
# Out:
# array(['HOMBRE', 'MUJER', 'NO ASIGNADO'], dtype=object)

# %%
df_from_xls["SEXO"] = df_from_xls["SEXO"].replace({"NO ASIGNADO":'NO_ASIGNADO'}, regex=True)

# %%
df_from_xls["SEXO"].unique()
# Out:
# array(['HOMBRE', 'MUJER', 'NO_ASIGNADO'], dtype=object)

# %%
df_from_xls.head()
# Out:
#         FECHA   HORA DIA_SEMANA            DISTRITO  NUM_PERSONAS  \
# 0  01/01/2010  00:00    VIERNES           CHAMARTIN             1
# 1  01/01/2010  00:00    VIERNES           CHAMARTIN             1
# 2  01/01/2010  00:00    VIERNES           CHAMARTIN             1
# 3  01/01/2010  01:00    VIERNES  PUENTE DE VALLECAS             7
# 4  01/01/2010  01:00    VIERNES  PUENTE DE VALLECAS             7
#
#       TIPO_ACCIDENTE TIPO_VEHICULO TIPO_PERSONA    SEXO     LESIVIDAD  \
# 0     COLISIÓN DOBLE       TURISMO    CONDUCTOR  HOMBRE  INGRESO_LEVE
# 1     COLISIÓN DOBLE       TURISMO    CONDUCTOR  HOMBRE  INGRESO_LEVE
# 2     COLISIÓN DOBLE       TURISMO      VIAJERO   MUJER   HERIDO_LEVE
# 3  COLISIÓN MÚLTIPLE   NO ASIGNADO      VIAJERO   MUJER   HERIDO_LEVE
# 4  COLISIÓN MÚLTIPLE   NO ASIGNADO      VIAJERO   MUJER   HERIDO_LEVE
#
#   EDAD_APROX
# 0         20
# 1         50
# 2         40
# 3         25
# 4         30

# %%
df_from_xls["TIPO_PERSONA"].unique()
# Out:
# array(['CONDUCTOR', 'VIAJERO', 'TESTIGO', 'PEATON'], dtype=object)

# %%
df_from_xls["TIPO_VEHICULO"].unique()
# Out:
# array(['TURISMO', 'NO ASIGNADO', 'FURGONETA', 'MOTOCICLETA', 'AUTO-TAXI',
#        'VARIOS', 'CAMION', 'CICLOMOTOR', 'AUTOBUS-AUTOCAR', 'BICICLETA',
#        'AMBULANCIA'], dtype=object)

# %%
df_from_xls["TIPO_VEHICULO"] = df_from_xls["TIPO_VEHICULO"].replace({"NO ASIGNADO":'NO_ASIGNADO'}, regex=True)
df_from_xls["TIPO_VEHICULO"] = df_from_xls["TIPO_VEHICULO"].replace({"AUTO-TAXI":'AUTO_TAXI'}, regex=True)
df_from_xls["TIPO_VEHICULO"] = df_from_xls["TIPO_VEHICULO"].replace({"AUTOBUS-AUTOCAR":'AUTOBUS_AUTOCAR'}, regex=True)

# %%
df_from_xls["TIPO_VEHICULO"].unique()
# Out:
# array(['TURISMO', 'NO_ASIGNADO', 'FURGONETA', 'MOTOCICLETA', 'AUTO_TAXI',
#        'VARIOS', 'CAMION', 'CICLOMOTOR', 'AUTOBUS_AUTOCAR', 'BICICLETA',
#        'AMBULANCIA'], dtype=object)

# %%
df_from_xls.head()
# Out:
#         FECHA   HORA DIA_SEMANA            DISTRITO  NUM_PERSONAS  \
# 0  01/01/2010  00:00    VIERNES           CHAMARTIN             1
# 1  01/01/2010  00:00    VIERNES           CHAMARTIN             1
# 2  01/01/2010  00:00    VIERNES           CHAMARTIN             1
# 3  01/01/2010  01:00    VIERNES  PUENTE DE VALLECAS             7
# 4  01/01/2010  01:00    VIERNES  PUENTE DE VALLECAS             7
#
#       TIPO_ACCIDENTE TIPO_VEHICULO TIPO_PERSONA    SEXO     LESIVIDAD  \
# 0     COLISIÓN DOBLE       TURISMO    CONDUCTOR  HOMBRE  INGRESO_LEVE
# 1     COLISIÓN DOBLE       TURISMO    CONDUCTOR  HOMBRE  INGRESO_LEVE
# 2     COLISIÓN DOBLE       TURISMO      VIAJERO   MUJER   HERIDO_LEVE
# 3  COLISIÓN MÚLTIPLE   NO_ASIGNADO      VIAJERO   MUJER   HERIDO_LEVE
# 4  COLISIÓN MÚLTIPLE   NO_ASIGNADO      VIAJERO   MUJER   HERIDO_LEVE
#
#   EDAD_APROX
# 0         20
# 1         50
# 2         40
# 3         25
# 4         30

# %%
df_from_xls["TIPO_ACCIDENTE"].unique()
# Out:
# array(['COLISIÓN DOBLE', 'COLISIÓN MÚLTIPLE', 'CHOQUE CON OBJETO FIJO',
#        'CAÍDA MOTOCICLETA', 'ATROPELLO', 'VUELCO', 'CAÍDA CICLOMOTOR',
#        'CAÍDA VIAJERO BUS', 'OTRAS CAUSAS', 'CAÍDA BICICLETA'],
#       dtype=object)

# %%
df_from_xls["TIPO_ACCIDENTE"] = df_from_xls["TIPO_ACCIDENTE"].replace({"COLISIÓN DOBLE":'COLISION_DOBLE'}, regex=True)
df_from_xls["TIPO_ACCIDENTE"] = df_from_xls["TIPO_ACCIDENTE"].replace({"COLISIÓN MÚLTIPLE":'COLISION_MULTIPLE'}, regex=True)
df_from_xls["TIPO_ACCIDENTE"] = df_from_xls["TIPO_ACCIDENTE"].replace({"CHOQUE CON OBJETO FIJO":'CHOQUE_CON_OBJETO_FIJO'}, regex=True)
df_from_xls["TIPO_ACCIDENTE"] = df_from_xls["TIPO_ACCIDENTE"].replace({"CAÍDA ":'CAIDA_'}, regex=True)
df_from_xls["TIPO_ACCIDENTE"] = df_from_xls["TIPO_ACCIDENTE"].replace({"OTRAS CAUSAS":'OTRAS_CAUSAS'}, regex=True)

# %%
df_from_xls["TIPO_ACCIDENTE"].unique()
# Out:
# array(['COLISION_DOBLE', 'COLISION_MULTIPLE', 'CHOQUE_CON_OBJETO_FIJO',
#        'CAIDA_MOTOCICLETA', 'ATROPELLO', 'VUELCO', 'CAIDA_CICLOMOTOR',
#        'CAIDA_VIAJERO BUS', 'OTRAS_CAUSAS', 'CAIDA_BICICLETA'],
#       dtype=object)

# %%
df_from_xls.head(3)
# Out:
#         FECHA   HORA DIA_SEMANA   DISTRITO  NUM_PERSONAS  TIPO_ACCIDENTE  \
# 0  01/01/2010  00:00    VIERNES  CHAMARTIN             1  COLISION_DOBLE
# 1  01/01/2010  00:00    VIERNES  CHAMARTIN             1  COLISION_DOBLE
# 2  01/01/2010  00:00    VIERNES  CHAMARTIN             1  COLISION_DOBLE
#
#   TIPO_VEHICULO TIPO_PERSONA    SEXO     LESIVIDAD EDAD_APROX
# 0       TURISMO    CONDUCTOR  HOMBRE  INGRESO_LEVE         20
# 1       TURISMO    CONDUCTOR  HOMBRE  INGRESO_LEVE         50
# 2       TURISMO      VIAJERO   MUJER   HERIDO_LEVE         40

# %%
df_from_xls["NUM_PERSONAS"].unique()
# Out:
# array([ 1,  7,  2,  3,  4,  5,  9,  6,  8, 18, 13])

# %%
personas_implicadas = df_from_xls["NUM_PERSONAS"].groupby([df_from_xls["FECHA"], df_from_xls["HORA"]]).agg({'count'})
personas_implicadas
# Out:
#                   count
# FECHA      HORA
# 01/01/2010 00:00      3
#            01:00      8
#            02:00      2
#            04:00     11
#            05:00      3
#            08:00      2
#            09:00      6
#            20:00      5
#            21:00     12
# 01/02/2010 09:00      5
#            10:00      5
#            11:00      3
#            12:00     12
#            13:00      5
#            14:00     15
#            15:00      3
#            17:00      2
#            18:00      6
#            19:00      3
#            20:00      6
#            21:00      7
#            22:00     12
# 01/03/2010 01:00      2
#            06:00      2
#            08:00      4
#            09:00     10
#            11:00      6
#            13:00      2
#            14:00      2
#            15:00      9
# ...                 ...
# 31/10/2010 02:00      2
#            03:00     12
#            04:00      4
#            06:00      3
#            08:00      3
#            09:00      2
#            12:00      2
#            13:00      9
#            15:00      2
#            17:00      2
#            18:00      4
#            19:00      3
#            23:00      2
# 31/12/2010 00:00      1
#            02:00      7
#            04:00      4
#            06:00      5
#            09:00      4
#            10:00      3
#            11:00      4
#            12:00      8
#            14:00      9
#            15:00      2
#            16:00      5
#            17:00      3
#            18:00      1
#            19:00      5
#            20:00      1
#            21:00      1
#            23:00      3
#
# [4964 rows x 1 columns]

# %%
type(personas_implicadas)
# Out:
# pandas.core.frame.DataFrame

# %%
#?pd.merge

# %%
personas_implicadas = personas_implicadas.rename(columns = {'count':'NUM_PERS_IMPLS'})
personas_implicadas.head()
# Out:
#                   NUM_PERS_IMPLS
# FECHA      HORA
# 01/01/2010 00:00               3
#            01:00               8
#            02:00               2
#            04:00              11
#            05:00               3

# %%
from functools import reduce
dffxls_join_perimp = [df_from_xls, personas_implicadas]
#Assuming they have two common column, I'd do the following:
df_from_xls = reduce(lambda left,right: pd.merge(left,right,on=['FECHA','HORA']), dffxls_join_perimp)
df_from_xls
# Out:
#             FECHA   HORA DIA_SEMANA             DISTRITO  NUM_PERSONAS  \
# 0      01/01/2010  00:00    VIERNES            CHAMARTIN             1
# 1      01/01/2010  00:00    VIERNES            CHAMARTIN             1
# 2      01/01/2010  00:00    VIERNES            CHAMARTIN             1
# 3      01/01/2010  01:00    VIERNES   PUENTE DE VALLECAS             7
# 4      01/01/2010  01:00    VIERNES   PUENTE DE VALLECAS             7
# 5      01/01/2010  01:00    VIERNES   PUENTE DE VALLECAS             7
# 6      01/01/2010  01:00    VIERNES   PUENTE DE VALLECAS             7
# 7      01/01/2010  01:00    VIERNES   PUENTE DE VALLECAS             7
# 8      01/01/2010  01:00    VIERNES   PUENTE DE VALLECAS             7
# 9      01/01/2010  01:00    VIERNES   PUENTE DE VALLECAS             7
# 10     01/01/2010  01:00    VIERNES   PUENTE DE VALLECAS             7
# 11     01/01/2010  02:00    VIERNES             CHAMBERI             1
# 12     01/01/2010  02:00    VIERNES             CHAMBERI             1
# 13     01/01/2010  04:00    VIERNES               RETIRO             7
# 14     01/01/2010  04:00    VIERNES               RETIRO             7
# 15     01/01/2010  04:00    VIERNES               RETIRO             7
# 16     01/01/2010  04:00    VIERNES               RETIRO             7
# 17     01/01/2010  04:00    VIERNES               RETIRO             7
# 18     01/01/2010  04:00    VIERNES               RETIRO             7
# 19     01/01/2010  04:00    VIERNES               RETIRO             7
# 20     01/01/2010  04:00    VIERNES               RETIRO             7
# 21     01/01/2010  04:00    VIERNES               RETIRO             7
# 22     01/01/2010  04:00    VIERNES               RETIRO             7
# 23     01/01/2010  04:00    VIERNES               RETIRO             7
# 13          COLISION_MULTIPLE   NO_ASIGNADO      TESTIGO  HOMBRE
# 14          COLISION_MULTIPLE   NO_ASIGNADO      TESTIGO  HOMBRE
# 15          COLISION_MULTIPLE       TURISMO    CONDUCTOR  HOMBRE
# 16          COLISION_MULTIPLE       TURISMO      VIAJERO  HOMBRE
# 17          COLISION_MULTIPLE       TURISMO      VIAJERO   MUJER
# 18          COLISION_MULTIPLE       TURISMO      VIAJERO   MUJER
# 19          COLISION_MULTIPLE       TURISMO      VIAJERO   MUJER
# 20          COLISION_MULTIPLE   MOTOCICLETA    CONDUCTOR  HOMBRE
# 21          COLISION_MULTIPLE        VARIOS    CONDUCTOR  HOMBRE
# 22          COLISION_MULTIPLE        VARIOS      VIAJERO   MUJER
# 23          COLISION_MULTIPLE        VARIOS      VIAJERO  HOMBRE
# 24             COLISION_DOBLE       TURISMO    CONDUCTOR  HOMBRE
# 25             COLISION_DOBLE       TURISMO    CONDUCTOR   MUJER
# 26             COLISION_DOBLE       TURISMO      VIAJERO  HOMBRE
# 27     CHOQUE_CON_OBJETO_FIJO       TURISMO    CONDUCTOR  HOMBRE
# 28     CHOQUE_CON_OBJETO_FIJO       TURISMO      VIAJERO  HOMBRE
# 29          CAIDA_MOTOCICLETA   MOTOCICLETA    CONDUCTOR  HOMBRE
# ...                       ...           ...          ...     ...
# 26548          COLISION_DOBLE       TURISMO    CONDUCTOR  HOMBRE
# 26549          COLISION_DOBLE       TURISMO      VIAJERO   MUJER
# 26550          COLISION_DOBLE    CICLOMOTOR    CONDUCTOR  HOMBRE
# 26551               ATROPELLO   NO_ASIGNADO       PEATON  HOMBRE
# 26552               ATROPELLO       TURISMO    CONDUCTOR   MUJER
# 26553               ATROPELLO       TURISMO    CONDUCTOR  HOMBRE
# 26554               ATROPELLO   NO_ASIGNADO       PEATON  HOMBRE
# 26555               ATROPELLO       TURISMO    CONDUCTOR   MUJER
# 26556               ATROPELLO       TURISMO      VIAJERO   MUJER
# 26557          COLISION_DOBLE       TURISMO    CONDUCTOR  HOMBRE
# 26558          COLISION_DOBLE       TURISMO    CONDUCTOR  HOMBRE
# 26559       COLISION_MULTIPLE       TURISMO    CONDUCTOR  HOMBRE
# 26560       COLISION_MULTIPLE       TURISMO    CONDUCTOR  HOMBRE
# 26561       COLISION_MULTIPLE       TURISMO    CONDUCTOR  HOMBRE
# 26562       COLISION_MULTIPLE       TURISMO      VIAJERO  HOMBRE
# 26563       COLISION_MULTIPLE       TURISMO      VIAJERO  HOMBRE
# 26564          COLISION_DOBLE   NO_ASIGNADO      TESTIGO  HOMBRE
# 26565          COLISION_DOBLE       TURISMO    CONDUCTOR   MUJER
# 26566          COLISION_DOBLE   MOTOCICLETA    CONDUCTOR  HOMBRE
# 26567        CAIDA_CICLOMOTOR    CICLOMOTOR    CONDUCTOR   MUJER
# 26568  CHOQUE_CON_OBJETO_FIJO   NO_ASIGNADO      TESTIGO  HOMBRE
# 26569  CHOQUE_CON_OBJETO_FIJO       TURISMO    CONDUCTOR  HOMBRE
# 26570               ATROPELLO   NO_ASIGNADO       PEATON   MUJER
# 26571               ATROPELLO   NO_ASIGNADO      TESTIGO  HOMBRE
# 26572               ATROPELLO       TURISMO    CONDUCTOR  HOMBRE
# 26573       CAIDA_MOTOCICLETA   MOTOCICLETA    CONDUCTOR  HOMBRE
# 26574  CHOQUE_CON_OBJETO_FIJO   MOTOCICLETA    CONDUCTOR  HOMBRE
# 26575               ATROPELLO   NO_ASIGNADO       PEATON  HOMBRE
# 26576               ATROPELLO       TURISMO    CONDUCTOR   MUJER
# 26577               ATROPELLO       TURISMO      VIAJERO  HOMBRE
#
#           LESIVIDAD EDAD_APROX  NUM_PERS_IMPLS
# 0      INGRESO_LEVE         20               3
# 1      INGRESO_LEVE         50               3
# 2       HERIDO_LEVE         40               3
# 3       HERIDO_LEVE         25               8
# 4       HERIDO_LEVE         30               8
# 5       HERIDO_LEVE         25               8
# 6       HERIDO_LEVE         25               8
# 7      INGRESO_LEVE         25               8
# 8       HERIDO_LEVE         25               8
# 9       HERIDO_LEVE         25               8
# 10      HERIDO_LEVE         25               8
# 11      HERIDO_LEVE         35               2
# 12     INGRESO_LEVE         35               2
# 13     INGRESO_LEVE         25              11
# 14     INGRESO_LEVE         30              11
# 15      HERIDO_LEVE         25              11
# 16     INGRESO_LEVE         30              11
# 17     INGRESO_LEVE         20              11
# 18     HERIDO_GRAVE         25              11
# 19      HERIDO_LEVE         25              11
# 20      HERIDO_LEVE         30              11
# 21      HERIDO_LEVE         20              11
# 22      HERIDO_LEVE         25              11
# 23      HERIDO_LEVE         20              11
# 24      HERIDO_LEVE         65               3
# 25     INGRESO_LEVE         25               3
# 26     INGRESO_LEVE         25               3
# 27      HERIDO_LEVE         35               2
# 28      HERIDO_LEVE         45               2
# 29      HERIDO_LEVE         30               6
# ...             ...        ...             ...
# 26548  INGRESO_LEVE         35               9
# 26549  INGRESO_LEVE         30               9
# 26550  HERIDO_GRAVE         25               9
# 26551   HERIDO_LEVE         20               9
# 26552  INGRESO_LEVE         25               9
# 26553  INGRESO_LEVE         25               9
# 26554   HERIDO_LEVE         65               9
# 26555  INGRESO_LEVE         25               9
# 26556  INGRESO_LEVE         75               9
# 26557  INGRESO_LEVE         25               2
# 26558   HERIDO_LEVE         30               2
# 26559  INGRESO_LEVE          0               5
# 26560  INGRESO_LEVE         35               5
# 26561   HERIDO_LEVE         25               5
# 26562   HERIDO_LEVE          0               5
# 26563   HERIDO_LEVE         25               5
# 26564  INGRESO_LEVE         20               3
# 26565  INGRESO_LEVE         50               3
# 26566   HERIDO_LEVE         35               3
# 26567   HERIDO_LEVE         40               1
# 26568  INGRESO_LEVE         25               5
# 26569   HERIDO_LEVE         25               5
# 26570   HERIDO_LEVE         30               5
# 26571  INGRESO_LEVE         30               5
# 26572  INGRESO_LEVE         20               5
# 26573   HERIDO_LEVE         45               1
# 26574   HERIDO_LEVE         30               1
# 26575   HERIDO_LEVE         40               3
# 26576  INGRESO_LEVE         25               3
# 26577  INGRESO_LEVE         55               3
#
# [26578 rows x 12 columns]

# %%
df_from_xls.columns
# Out:
# Index(['FECHA', 'HORA', 'DIA_SEMANA', 'DISTRITO', 'NUM_PERSONAS',
#        'TIPO_ACCIDENTE', 'TIPO_VEHICULO', 'TIPO_PERSONA', 'SEXO', 'LESIVIDAD',
#        'EDAD_APROX', 'NUM_PERS_IMPLS'],
#       dtype='object')

# %%
df_from_xls = df_from_xls.rename(columns = {'count':'NUM_PERS_IMPLS'})
df_from_xls.head()
# Out:
#         FECHA   HORA DIA_SEMANA            DISTRITO  NUM_PERSONAS  \
# 0  01/01/2010  00:00    VIERNES           CHAMARTIN             1
# 1  01/01/2010  00:00    VIERNES           CHAMARTIN             1
# 2  01/01/2010  00:00    VIERNES           CHAMARTIN             1
# 3  01/01/2010  01:00    VIERNES  PUENTE DE VALLECAS             7
# 4  01/01/2010  01:00    VIERNES  PUENTE DE VALLECAS             7
#
#       TIPO_ACCIDENTE TIPO_VEHICULO TIPO_PERSONA    SEXO     LESIVIDAD  \
# 0     COLISION_DOBLE       TURISMO    CONDUCTOR  HOMBRE  INGRESO_LEVE
# 1     COLISION_DOBLE       TURISMO    CONDUCTOR  HOMBRE  INGRESO_LEVE
# 2     COLISION_DOBLE       TURISMO      VIAJERO   MUJER   HERIDO_LEVE
# 3  COLISION_MULTIPLE   NO_ASIGNADO      VIAJERO   MUJER   HERIDO_LEVE
# 4  COLISION_MULTIPLE   NO_ASIGNADO      VIAJERO   MUJER   HERIDO_LEVE
#
#   EDAD_APROX  NUM_PERS_IMPLS
# 0         20               3
# 1         50               3
# 2         40               3
# 3         25               8
# 4         30               8

# %%
df_from_xls.columns
# Out:
# Index(['FECHA', 'HORA', 'DIA_SEMANA', 'DISTRITO', 'NUM_PERSONAS',
#        'TIPO_ACCIDENTE', 'TIPO_VEHICULO', 'TIPO_PERSONA', 'SEXO', 'LESIVIDAD',
#        'EDAD_APROX', 'NUM_PERS_IMPLS'],
#       dtype='object')

# %%
del df_from_xls["NUM_PERSONAS"]
df_from_xls.columns
# Out:
# Index(['FECHA', 'HORA', 'DIA_SEMANA', 'DISTRITO', 'TIPO_ACCIDENTE',
#        'TIPO_VEHICULO', 'TIPO_PERSONA', 'SEXO', 'LESIVIDAD', 'EDAD_APROX',
#        'NUM_PERS_IMPLS'],
#       dtype='object')

# %%
df_from_xls.head(1)
# Out:
#         FECHA   HORA DIA_SEMANA   DISTRITO  TIPO_ACCIDENTE TIPO_VEHICULO  \
# 0  01/01/2010  00:00    VIERNES  CHAMARTIN  COLISION_DOBLE       TURISMO
#
#   TIPO_PERSONA    SEXO     LESIVIDAD EDAD_APROX  NUM_PERS_IMPLS
# 0    CONDUCTOR  HOMBRE  INGRESO_LEVE         20               3

# %%
personas_implicadas.head()
# Out:
#                   NUM_PERS_IMPLS
# FECHA      HORA
# 01/01/2010 00:00               3
#            01:00               8
#            02:00               2
#            04:00              11
#            05:00               3

# %%
# reset the index 
personas_implicadas = personas_implicadas.reset_index() 
  
# Print the result 
# print(personas_implicadas)

# %%
personas_implicadas.head()
# Out:
#         FECHA   HORA  NUM_PERS_IMPLS
# 0  01/01/2010  00:00               3
# 1  01/01/2010  01:00               8
# 2  01/01/2010  02:00               2
# 3  01/01/2010  04:00              11
# 4  01/01/2010  05:00               3

# %%
type(personas_implicadas)
# Out:
# pandas.core.frame.DataFrame

# %%
personas_implicadas.columns
# Out:
# Index(['FECHA', 'HORA', 'NUM_PERS_IMPLS'], dtype='object')

# %%
personas_implicadas.dtypes
# Out:
# FECHA             object
# HORA              object
# NUM_PERS_IMPLS     int64
# dtype: object

# %%
personas_implicadas.head(1)
# Out:
#         FECHA   HORA  NUM_PERS_IMPLS
# 0  01/01/2010  00:00               3

# %%
personas_implicadas.tail(1)
# Out:
#            FECHA   HORA  NUM_PERS_IMPLS
# 4963  31/12/2010  23:00               3

# %%
type(personas_implicadas["FECHA"])
# Out:
# pandas.core.series.Series

# %%
type(personas_implicadas["HORA"])
# Out:
# pandas.core.series.Series

# %%
personas_implicadas.columns
# Out:
# Index(['FECHA', 'HORA', 'NUM_PERS_IMPLS'], dtype='object')

# %%
personas_implicadas.dtypes
# Out:
# FECHA             object
# HORA              object
# NUM_PERS_IMPLS     int64
# dtype: object

# %%
personas_implicadas.columns
# Out:
# Index(['FECHA', 'HORA', 'NUM_PERS_IMPLS'], dtype='object')

# %%
personas_implicadas.dtypes
# Out:
# FECHA             object
# HORA              object
# NUM_PERS_IMPLS     int64
# dtype: object

# %%
personas_implicadas["FECHA_HORA"] = personas_implicadas["FECHA"] + ' ' + personas_implicadas["HORA"]

# %%
personas_implicadas.columns
# Out:
# Index(['FECHA', 'HORA', 'NUM_PERS_IMPLS', 'FECHA_HORA'], dtype='object')

# %%
personas_implicadas["FECHA_HORA"][0]
# Out:
# '01/01/2010 00:00'

# %%
personas_implicadas.dtypes
# Out:
# FECHA             object
# HORA              object
# NUM_PERS_IMPLS     int64
# FECHA_HORA        object
# dtype: object

# %%
del personas_implicadas["FECHA"]
del personas_implicadas["HORA"]

# %%
personas_implicadas.columns
# Out:
# Index(['NUM_PERS_IMPLS', 'FECHA_HORA'], dtype='object')

# %%
personas_implicadas["NPI_AUX"]=personas_implicadas["NUM_PERS_IMPLS"]

# %%
personas_implicadas.columns
# Out:
# Index(['NUM_PERS_IMPLS', 'FECHA_HORA', 'NPI_AUX'], dtype='object')

# %%
personas_implicadas.dtypes
# Out:
# NUM_PERS_IMPLS     int64
# FECHA_HORA        object
# NPI_AUX            int64
# dtype: object

# %%
del personas_implicadas["NUM_PERS_IMPLS"]

# %%
personas_implicadas.dtypes
# Out:
# FECHA_HORA    object
# NPI_AUX        int64
# dtype: object

# %%
personas_implicadas.columns
# Out:
# Index(['FECHA_HORA', 'NPI_AUX'], dtype='object')

# %%
personas_implicadas=personas_implicadas.rename(columns = {'NPI_AUX':'NUM_PERS_IMPLS'})

# %%
personas_implicadas.dtypes
# Out:
# FECHA_HORA        object
# NUM_PERS_IMPLS     int64
# dtype: object

# %%
personas_implicadas.head(1)
# Out:
#          FECHA_HORA  NUM_PERS_IMPLS
# 0  01/01/2010 00:00               3

# %%
personas_implicadas["FECHA_HORA"] = pd.to_datetime(pd.Series(personas_implicadas["FECHA_HORA"]), format="%d/%m/%Y %H:%M")

# %%
type(personas_implicadas["FECHA_HORA"])
# Out:
# pandas.core.series.Series

# %%
personas_implicadas.head(1)
# Out:
#   FECHA_HORA  NUM_PERS_IMPLS
# 0 2010-01-01               3

# %%
personas_implicadas["FECHA_HORA"][0]
# Out:
# Timestamp('2010-01-01 00:00:00')

# %%
personas_implicadas.columns
# Out:
# Index(['FECHA_HORA', 'NUM_PERS_IMPLS'], dtype='object')

# %%
personas_implicadas.dtypes
# Out:
# FECHA_HORA        datetime64[ns]
# NUM_PERS_IMPLS             int64
# dtype: object

# %%
personas_implicadas.head(5)
# Out:
#            FECHA_HORA  NUM_PERS_IMPLS
# 0 2010-01-01 00:00:00               3
# 1 2010-01-01 01:00:00               8
# 2 2010-01-01 02:00:00               2
# 3 2010-01-01 04:00:00              11
# 4 2010-01-01 05:00:00               3

# %%
df_from_xls.head()
# Out:
#         FECHA   HORA DIA_SEMANA            DISTRITO     TIPO_ACCIDENTE  \
# 0  01/01/2010  00:00    VIERNES           CHAMARTIN     COLISION_DOBLE
# 1  01/01/2010  00:00    VIERNES           CHAMARTIN     COLISION_DOBLE
# 2  01/01/2010  00:00    VIERNES           CHAMARTIN     COLISION_DOBLE
# 3  01/01/2010  01:00    VIERNES  PUENTE DE VALLECAS  COLISION_MULTIPLE
# 4  01/01/2010  01:00    VIERNES  PUENTE DE VALLECAS  COLISION_MULTIPLE
#
#   TIPO_VEHICULO TIPO_PERSONA    SEXO     LESIVIDAD EDAD_APROX  NUM_PERS_IMPLS
# 0       TURISMO    CONDUCTOR  HOMBRE  INGRESO_LEVE         20               3
# 1       TURISMO    CONDUCTOR  HOMBRE  INGRESO_LEVE         50               3
# 2       TURISMO      VIAJERO   MUJER   HERIDO_LEVE         40               3
# 3   NO_ASIGNADO      VIAJERO   MUJER   HERIDO_LEVE         25               8
# 4   NO_ASIGNADO      VIAJERO   MUJER   HERIDO_LEVE         30               8

# %%
personas_implicadas.count()
# Out:
# FECHA_HORA        4964
# NUM_PERS_IMPLS    4964
# dtype: int64

# %%
calendario = pd.date_range(start='2010-01-01 00:00:00', end='2010-01-31 23:00:00', freq='1H')
calendario = pd.DataFrame(calendario, columns=['FECHA'])
#print(calendario)
calendario["FECHA"].head(5)
# Out:
# 0   2010-01-01 00:00:00
# 1   2010-01-01 01:00:00
# 2   2010-01-01 02:00:00
# 3   2010-01-01 03:00:00
# 4   2010-01-01 04:00:00
# Name: FECHA, dtype: datetime64[ns]

# %%
type(calendario)
# Out:
# pandas.core.frame.DataFrame

# %%
type(calendario["FECHA"])
# Out:
# pandas.core.series.Series

# %%
calendario.dtypes
# Out:
# FECHA    datetime64[ns]
# dtype: object

# %%
#['left', 'right', "how='inner'", 'on=None', 'left_on=None', 'right_on=None', 'left_index=False', 
#'right_index=False', 'sort=False', "suffixes=('_x', '_y')", 'copy=True', 'indicator=False', 'validate=None']
df_cal_join_pim = [calendario, personas_implicadas]
df_series_tiempo = reduce(lambda left,right: pd.merge(left,right,how='left',left_on='FECHA',\
                                                      right_on='FECHA_HORA',validate='one_to_one'), df_cal_join_pim)
df_series_tiempo.head(5)
# Out:
#                 FECHA          FECHA_HORA  NUM_PERS_IMPLS
# 0 2010-01-01 00:00:00 2010-01-01 00:00:00             3.0
# 1 2010-01-01 01:00:00 2010-01-01 01:00:00             8.0
# 2 2010-01-01 02:00:00 2010-01-01 02:00:00             2.0
# 3 2010-01-01 03:00:00                 NaT             NaN
# 4 2010-01-01 04:00:00 2010-01-01 04:00:00            11.0

# %%
del df_series_tiempo["FECHA_HORA"]

# %%
df_series_tiempo.columns
# Out:
# Index(['FECHA', 'NUM_PERS_IMPLS'], dtype='object')

# %%
df_series_tiempo.head(5)
# Out:
#                 FECHA  NUM_PERS_IMPLS
# 0 2010-01-01 00:00:00             3.0
# 1 2010-01-01 01:00:00             8.0
# 2 2010-01-01 02:00:00             2.0
# 3 2010-01-01 03:00:00             NaN
# 4 2010-01-01 04:00:00            11.0

# %%
df_series_tiempo.dtypes
# Out:
# FECHA             datetime64[ns]
# NUM_PERS_IMPLS           float64
# dtype: object

# %%
df_series_tiempo=df_series_tiempo.combine_first(df_series_tiempo.select_dtypes(include=[np.number]).fillna(0))

# %%
df_series_tiempo.dtypes
# Out:
# FECHA             datetime64[ns]
# NUM_PERS_IMPLS           float64
# dtype: object

# %%
df_series_tiempo.head(5)
# Out:
#                 FECHA  NUM_PERS_IMPLS
# 0 2010-01-01 00:00:00             3.0
# 1 2010-01-01 01:00:00             8.0
# 2 2010-01-01 02:00:00             2.0
# 3 2010-01-01 03:00:00             0.0
# 4 2010-01-01 04:00:00            11.0

# %%
df_series_tiempo["NUM_PERS_IMPLS"]=df_series_tiempo['NUM_PERS_IMPLS'].astype(np.int64)

# %%
df_series_tiempo.dtypes
# Out:
# FECHA             datetime64[ns]
# NUM_PERS_IMPLS             int64
# dtype: object

# %%
df_series_tiempo.head(5)
# Out:
#                 FECHA  NUM_PERS_IMPLS
# 0 2010-01-01 00:00:00               3
# 1 2010-01-01 01:00:00               8
# 2 2010-01-01 02:00:00               2
# 3 2010-01-01 03:00:00               0
# 4 2010-01-01 04:00:00              11

# %%
############################### INICIO

# %%
# convertir indice el campo FECHA
df_series_tiempo.reset_index(inplace=True)
df_series_tiempo['FECHA'] = pd.to_datetime(df_series_tiempo['FECHA'])
df_series_tiempo = df_series_tiempo.set_index('FECHA')

# %%
df_series_tiempo.head(5)
# Out:
#                      index  NUM_PERS_IMPLS
# FECHA
# 2010-01-01 00:00:00      0               3
# 2010-01-01 01:00:00      1               8
# 2010-01-01 02:00:00      2               2
# 2010-01-01 03:00:00      3               0
# 2010-01-01 04:00:00      4              11

# %%
del df_series_tiempo['index']

# %%
df_series_tiempo.head(5)
# Out:
#                      NUM_PERS_IMPLS
# FECHA
# 2010-01-01 00:00:00               3
# 2010-01-01 01:00:00               8
# 2010-01-01 02:00:00               2
# 2010-01-01 03:00:00               0
# 2010-01-01 04:00:00              11

# %%
#################################################################### INICIO

# %%
import io
import pandas as pd

df_series_tiempo.plot(figsize=(20,4));

# %%
# Relación de confianza para la aleatoriedad en 0 y correlación al 99% y 95%
# Serie estacionari por ser menor del 0.5
from pandas.plotting import autocorrelation_plot
plt.figure(figsize=(20,5))

autocorrelation_plot(df_series_tiempo)

# %%
##############################

# %%
# PRIMERA ETAPA: representar gráficamente la serie para identificar la tendencia y la estacionalidad

# %%
# Esta función es utilizada para mostrar los gráficos
import matplotlib.pyplot as mplt 
#Se utilizará seaborn para el estilo de los gráficos y se ajustará el tamaño 
# de figura predeterminado a una forma más adecuada para las gráficas de series temporales.
import seaborn as sbn 
sbn.set(rc={'figure.figsize':(20, 5)})

# %%
# Descomponemos la serie temporal
import statsmodels.api as sm
s=sm.tsa.seasonal_decompose(df_series_tiempo)

# %%
#Se creará un gráfico de líneas de la series temporales completas, utilizando el método plot
s.resid.plot(linewidth=1)

# %%
s.seasonal.plot(linewidth=1)

# %%
s.trend.plot(linewidth=1)

# %%
nube_puntos = [s.resid, s.seasonal, s.trend]

# %%
type(nube_puntos)
# Out:
# list

# %%
ejes = s.resid.plot(marker='.', alpha=1, linestyle='None',figsize=(20,10),subplots=True)
for eje in ejes:
  eje.set_ylabel('Número de personas implicadas')

# %%
ejes = s.seasonal.plot(marker='.', alpha=1, linestyle='None',figsize=(20,10),subplots=True)
for eje in ejes:
  eje.set_ylabel('Número de personas implicadas')

# %%
ejes = s.trend.plot(marker='.', alpha=1, linestyle='None',figsize=(20,10),subplots=True)
for eje in ejes:
  eje.set_ylabel('Número de personas implicadas')

# %%
######## ESTACIONALIDAD

# %%
# Remuestreo de frecuencia para la media diaria
#columnas = ['name1','name2','namen']
media_diaria = df_series_tiempo["NUM_PERS_IMPLS"].resample('D').mean()
media_diaria.head(3)
# Out:
# FECHA
# 2010-01-01    2.166667
# 2010-01-02    1.750000
# 2010-01-03    1.916667
# Freq: D, Name: NUM_PERS_IMPLS, dtype: float64

# %%
# Remuestreo de frecuencia para la media semanal
#columnas = ['name1','name2','namen']
media_semanal = df_series_tiempo["NUM_PERS_IMPLS"].resample('W').mean()
media_semanal.head(3)
# Out:
# FECHA
# 2010-01-03    1.944444
# 2010-01-10    2.363095
# 2010-01-17    2.017857
# Freq: W-SUN, Name: NUM_PERS_IMPLS, dtype: float64

# %%
# Remuestreo de frecuencia para la media mensual
#columnas = ['name1','name2','namen']
media_mensual = df_series_tiempo["NUM_PERS_IMPLS"].resample('M').mean()
media_mensual.head(3)
# Out:
# FECHA
# 2010-01-31    2.426075
# Freq: M, Name: NUM_PERS_IMPLS, dtype: float64

# %%
# Remuestreo de frecuencia para la media anual
#columnas = ['name1','name2','namen']
media_anual = df_series_tiempo["NUM_PERS_IMPLS"].resample('Y').mean()
media_anual.head(3)
# Out:
# FECHA
# 2010-12-31    2.426075
# Freq: A-DEC, Name: NUM_PERS_IMPLS, dtype: float64

# %%
prueba.shape[0]
# Out:
# 744

# %%
media_diaria.shape[0]
# Out:
# 31

# %%
media_semanal.shape[0]
# Out:
# 5

# %%
media_mensual.shape[0]
# Out:
# 1

# %%
media_anual.shape[0]
# Out:
# 1

# %%
## Se trazarán las series temporales diarias y semanales juntas en un solo período de 1 mes para compararlas.
inicio, final = df_series_tiempo.index.values[0], df_series_tiempo.index.values[-1]
fig, eje = mplt.subplots()
#eje.plot(df_series_tiempo.loc[inicio:final,'NUM_PERS_IMPLS'], marker='.',linestyle='-',linewidth=0.5,label='Horas')
eje.plot(media_diaria,marker='o',markersize=5,label='Días')
eje.plot(media_semanal,marker='o',markersize=7,label='Semanas')
#eje.plot(media_mensual,marker='o',markersize=9,label='Meses')
#eje.plot(media_anual,marker='o',markersize=11,label='Años')
eje.set_ylabel('Número de personas implicadas')
eje.legend()

# %%
## Se trazarán las series temporales de visualización general.
inicio, final = df_series_tiempo.index.values[0], prueba.index.values[-1]
fig,eje = mplt.subplots()
eje.plot(prueba.loc[inicio:final,'NUM_PERS_IMPLS'], marker='.',linestyle='-',linewidth=0.5,label='Horas')
eje.plot(media_diaria,marker='o',markersize=5,label='Días')
eje.plot(media_semanal,marker='o',markersize=7,label='Semanas')
eje.plot(media_mensual,marker='o',markersize=9,label='Meses')
eje.plot(media_anual,marker='o',markersize=11,label='Años')
eje.set_ylabel('Número de personas implicadas')
eje.legend()

# %%
# Comprobar valores nulos
df_series_tiempo.isnull().sum()
# Out:
# NUM_PERS_IMPLS    0
# dtype: int64

# %%
media_diaria.isnull().sum()
# Out:
# 0

# %%
media_semanal.isnull().sum()
# Out:
# 0

# %%
media_mensual.isnull().sum()
# Out:
# 0

# %%
media_anual.isnull().sum()
# Out:
# 0

# %%
# ventanas deslizantes: superponen tiempos y “deslizan” a la misma frecuencia que los datos, 
# por lo que las series temporales transformadas tienen la misma frecuencia que las series temporales originales.
# la misma ponderacion
import pandas as pnd
import matplotlib.pyplot as mplt
import seaborn as sbn

# %%
sbn.set(rc={'figure.figsize':(20, 10)})
media_vd_semanal = df_series_tiempo["NUM_PERS_IMPLS"].rolling(168, center=True).mean()
inicio_vd, final_vd = df_series_tiempo.index.values[0], df_series_tiempo.index.values[-1]
fig_vd,eje_vd = mplt.subplots()
#eje_vd.plot(df_series_tiempo['NUM_PERS_IMPLS'], marker='.', markersize=2, color='0.6', linestyle='None', label='Horas')
eje_vd.plot(media_diaria,marker='o',markersize=5,linestyle='-', linewidth=0.5,label='Días')
eje_vd.plot(media_semanal,marker='o',markersize=7,linestyle='-', linewidth=0.5,label='Semanas')
eje_vd.plot(media_vd_semanal,marker='o',markersize=1,linestyle='-', linewidth=0.5,label='Media deslizante semanal (168hrs.)')
#eje_vd.plot(media_vd_semanal, linewidth=2, label='Media deslizante semanal')
#eje_vd.plot(media_anual,marker='o',markersize=11,label='Años')
eje_vd.legend()
eje_vd.set_xlabel('Semanas')
eje_vd.set_ylabel('Número de personas implicadas')
eje_vd.set_title('Tendencias de personas implicadas en accidentes de tráfico')
# Out:
# Text(0.5, 1.0, 'Tendencias de personas implicadas en accidentes de tráfico')

# %%
# comprobar Prueba de Dicky-Fuller (DF-test) proporciona una manera más precisa de medir 
# la estacionariedad de nuestra serie. (“Test Statistic” menor que todos los “Critical Value”)
# CONCLUSION: Serie estacionaria

# %%
import pandas as pd
from statsmodels.tsa.stattools import adfuller
# Perform Dickey-Fuller test:
# Por defecto con AIC, se emplea el argumento de regresión de deriva constante ('c'), centrando la serie en 0.
print ('Results of Dickey-Fuller Test:')
df_series_tiempo_DickeyFuller = df_series_tiempo.iloc[:,0].values
dftest_DF = adfuller(df_series_tiempo_DickeyFuller, autolag='AIC')
dfoutput_DF = pd.Series(dftest_DF[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest_DF[4].items():
    dfoutput_DF['Critical Value (%s)'%key] = value
print(dfoutput_DF)
# El resultado indica que la serie es estacionaria, rechazando la hipótesis nula al 0.05 (5%) por p-value
# y puesto que el Test Statistic, es más negativo que cualquiera de los valores críticos.
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -5.565552
# p-value                          0.000002
# #Lags Used                      20.000000
# Number of Observations Used    723.000000
# Critical Value (1%)             -3.439427
# Critical Value (5%)             -2.865546
# Critical Value (10%)            -2.568903
# dtype: float64

# %%
# Perform Dickey-Fuller test:
# Por defecto con AIC, se emplea el argumento de regresión de deriva constante ('c'), centrando la serie en 0.
# ahora pruebo con un estadístico mejor: # * 'ct' : constant and trend
print ('Results of Dickey-Fuller Test:')
dftest_DF_ct = adfuller(df_series_tiempo_DickeyFuller, regression='ct', autolag='AIC')
dfoutput_DF_ct = pd.Series(dftest_DF_ct[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest_DF_ct[4].items():
    dfoutput_DF['Critical Value (%s)'%key] = value
print(dfoutput_DF_ct)
# El resultado indica que la serie sigue siendo estacionaria, rechazando la hipótesis nula al 0.05 (5%) por p-value
# y puesto que el Test Statistic, es más negativo que cualquiera de los valores críticos.
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -5.795519
# p-value                          0.000006
# #Lags Used                      20.000000
# Number of Observations Used    723.000000
# dtype: float64

# %%
# plt.plot(df_series_tiempo)

# %%
# Por diferenciación
# df_series_tiempo_diff = df_series_tiempo - df_series_tiempo.shift()
# plt.plot(df_series_tiempo_diff)

# %%
# Análisis de los residuos: 
# debe verificarse el supuesto de que los errores del modelo son un proceso puramente aleatorio 
# (media cero, varianza constante y no correlación serial), es decir, que no tienen estructura de 
# dependencia (los residuos no deben estar correlacionados al pasado, deben ser independientes 
# los unos de los otros) y seguit un proceso de ruido blanco.

# %%
# FORECASTING PROBABILIDAD versus ALEATORIEDAD (bandas de Bartlett)
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
df_series_tiempo.mean()
# Out:
# NUM_PERS_IMPLS    2.426075
# dtype: float64

# %%
s.resid.mean()
# Out:
# NUM_PERS_IMPLS   -0.00978
# dtype: float64

# %%
s.seasonal.mean()
# Out:
# NUM_PERS_IMPLS    8.953411e-19
# dtype: float64

# %%
s.trend.mean()
# Out:
# NUM_PERS_IMPLS    2.445891
# dtype: float64

# %%
sbn.set(rc={'figure.figsize':(20, 5)})
plot_acf(df_series_tiempo)
pyplot.show()

# %%
plot_acf(df_series_tiempo, lags=168)
pyplot.show()

# %%
plot_acf(df_series_tiempo, lags=20)
pyplot.show()

# %%
plot_pacf(df_series_tiempo)
pyplot.show()
# Out:
# /home/dsc/anaconda3/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:1283: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %%
plot_pacf(df_series_tiempo, lags=168)
pyplot.show()

# %%
plot_pacf(df_series_tiempo, lags=20)
pyplot.show()

# %%
#################### PRUEBA APLICACION ARMA
# modelo que utiliza la máxima probabilidad exacta a través del filtro de Kalman
# mediante el método (mle), incluyendo constante, con el solucionador por defecto: limited memory BFGS uses m=12,
# imprimiendo la información de convergencia para los controles de frecuencia durante las iteraciones (disp=True),
# utilizando los residuos por defecto para el mejor resultado (start_ar_lags)

# %%
# %matplotlib inline

# %%
import numpy as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.graphics.api import qqplot

# %%
import seaborn as sbn

# %%
df_series_tiempo.plot(figsize=(20,5));

# %%
df_series_tiempo.shape
# Out:
# (744, 1)

# %%
# Plot con statsmodel reduciendo dimensionalidad a escalares con squeeze
fig_sm = plt.figure(figsize=(20,5))
ax1_sm = fig_sm.add_subplot(211)
fig_sm = sm.graphics.tsa.plot_acf(df_series_tiempo.values.squeeze(), lags=24, ax=ax1_sm)
ax2_sm = fig_sm.add_subplot(212)
fig_sm = sm.graphics.tsa.plot_pacf(df_series_tiempo, lags=24, ax=ax2_sm)

# %%
df_series_tiempo.shape
# Out:
# (744, 1)

# %%
df_series_tiempo.index
# Out:
# DatetimeIndex(['2010-01-01 00:00:00', '2010-01-01 01:00:00',
#                '2010-01-01 02:00:00', '2010-01-01 03:00:00',
#                '2010-01-01 04:00:00', '2010-01-01 05:00:00',
#                '2010-01-01 06:00:00', '2010-01-01 07:00:00',
#                '2010-01-01 08:00:00', '2010-01-01 09:00:00',
#                ...
#                '2010-01-31 14:00:00', '2010-01-31 15:00:00',
#                '2010-01-31 16:00:00', '2010-01-31 17:00:00',
#                '2010-01-31 18:00:00', '2010-01-31 19:00:00',
#                '2010-01-31 20:00:00', '2010-01-31 21:00:00',
#                '2010-01-31 22:00:00', '2010-01-31 23:00:00'],
#               dtype='datetime64[ns]', name='FECHA', length=744, freq=None)

# %%
df_series_tiempo.NUM_PERS_IMPLS.count()
# Out:
# 744

# %%
#?sm.tsa.ARMA.fit

# %%
#?sm.tsa.ARMA

# %%
#?df_series_tiempo.resample

# %%
# Remuestreo de frecuencia serie diaria
#columnas = ['name1','name2','namen']
df_series_tiempo_diaria = df_series_tiempo["NUM_PERS_IMPLS"].resample('D')
df_series_tiempo_diaria
# Out:
# DatetimeIndexResampler [freq=<Day>, axis=0, closed=left, label=left, convention=start, base=0]

# %%
# Remuestreo de frecuencia serie semanal
#columnas = ['name1','name2','namen']
df_series_tiempo_semanal = df_series_tiempo["NUM_PERS_IMPLS"].resample('W')
df_series_tiempo_semanal
# Out:
# DatetimeIndexResampler [freq=<Week: weekday=6>, axis=0, closed=right, label=right, convention=start, base=0]

# %%
# Remuestreo de frecuencia serie mensual
#columnas = ['name1','name2','namen']
df_series_tiempo_mensual = df_series_tiempo["NUM_PERS_IMPLS"].resample('M')
df_series_tiempo_mensual
# Out:
# DatetimeIndexResampler [freq=<MonthEnd>, axis=0, closed=right, label=right, convention=start, base=0]

# %%
# Remuestreo de frecuencia serie anual
#columnas = ['name1','name2','namen']
df_series_tiempo_anual = df_series_tiempo["NUM_PERS_IMPLS"].resample('Y')
df_series_tiempo_anual
# Out:
# DatetimeIndexResampler [freq=<YearEnd: month=12>, axis=0, closed=right, label=right, convention=start, base=0]

# %%
len(df_series_tiempo)
# Out:
# 744

# %%
len(df_series_tiempo_diaria)
# Out:
# 31

# %%
len(df_series_tiempo_semanal)
# Out:
# 5

# %%
len(df_series_tiempo_anual)
# Out:
# 1

# %%
# El conjunto de datos completo en la muestra contiene 744 observaciones, y sólo probamos a utilizar el primer 80% 
# como muestra, considerando pronósticos de un perido adelante.

# Step 1: entrenar modelos con parámetros de la muestra de entrenamiento.
training_size = int(len(df_series_tiempo) * 0.8)

training_df_series_tiempo = df_series_tiempo[:training_size]

# %%
# Para hacer frente a la posible futura estacionalidad, los procesos ARIMA han sido generalizados, 
# estableciendo los modelos SARIMA (Seasonal Autoregressive Integrated Moving Average Model).
# Estos, incluyen residuos
# Un modelo SARIMAX es un modelo de regresión lineal que utiliza un proceso de tipo SARIMA, 
# es decir este modelo es útil en los casos donde sospechamos que los residuos pueden exhibir 
# una tendencia estacional o patrón.

# %%
#?sm.tsa.SARIMAX

# %%
# MODELO SARIMA(1,0,0): Naive
#training_sarimamod100 = sm.tsa.SARIMAX(training_df_series_tiempo, order=(1,0,0), trend='c', freq='H')
#training_sarimamod100 = sm.tsa.SARIMAX(training_df_series_tiempo, order=(1,0,0), \
#                                       seasonal_order=(1, 1, 1, 52), trend='ct', freq='H',\
#                                       mle_regression=True, simple_differencing=False, \
#                                       enforce_stationarity=True, enforce_invertibility=True, 
#                                       hamilton_representation=False)
#training_res_sarimamod100 = training_sarimamod100.fit()

# Parámetros estimados
#print(training_res_sarimamod100.params)
# Out:
# intercept     0.232852
# drift        -0.000486
# ar.L1         0.194563
# ar.S.L52     -0.037383
# ma.S.L52     -0.839019
# sigma2       11.924246
# dtype: float64

# %%
# MODELO ARMA(0,0): Naive
training_armamod00 = sm.tsa.ARMA(training_df_series_tiempo, (0,0), freq='H')
training_res_armamod00 = training_armamod00.fit(method='mle', trend='c', disp=True)

# Parámetros estimados
print(training_res_armamod10.params)
# Out:
# const                   2.371444
# ar.L1.NUM_PERS_IMPLS    0.191652
# dtype: float64

# %%
#?sm.tsa.ARMA

# %%
# MODELO ARMA(1,0)
training_armamod10 = sm.tsa.ARMA(training_df_series_tiempo, (1,0), freq='H')
training_res_armamod10 = training_armamod10.fit(method='mle', trend='c', disp=True)

# Parámetros estimados
print(training_res_armamod10.params)
# Out:
# const                   2.371444
# ar.L1.NUM_PERS_IMPLS    0.191652
# dtype: float64

# %%
# MODELO ARMA(0,1)
training_armamod01 = sm.tsa.ARMA(training_df_series_tiempo, (0,1), freq='H')
training_res_armamod01 = training_armamod01.fit(method='mle', trend='c', disp=True)

# Parámetros estimados
print(training_res_armamod01.params)
# Out:
# const                   2.370758
# ma.L1.NUM_PERS_IMPLS    0.166468
# dtype: float64

# %%
# MODELO ARMA(1,1)
training_armamod11 = sm.tsa.ARMA(training_df_series_tiempo, (1,1), freq='H')
training_res_armamod11 = training_armamod11.fit(method='mle', trend='c', disp=True)

# Parámetros estimados
print(training_res_armamod11.params)
# Out:
# const                   2.375965
# ar.L1.NUM_PERS_IMPLS    0.690795
# ma.L1.NUM_PERS_IMPLS   -0.521870
# dtype: float64

# %%
# MODELO ARMA(2,0)
training_armamod20 = sm.tsa.ARMA(training_df_series_tiempo, (2,0), freq='H')
training_res_armamod20 = training_armamod20.fit(method='mle', trend='c', disp=True)

# Parámetros estimados
print(training_res_armamod20.params)
# Out:
# const                   2.373279
# ar.L1.NUM_PERS_IMPLS    0.173535
# ar.L2.NUM_PERS_IMPLS    0.094110
# dtype: float64

# %%
# MODELO ARMA(2,1)
training_armamod21 = sm.tsa.ARMA(training_df_series_tiempo, (2,1), freq='H')
training_res_armamod21 = training_armamod21.fit(method='mle', trend='c', disp=True)

# Parámetros estimados
print(training_res_armamod21.params)
# Out:
# const                   2.375921
# ar.L1.NUM_PERS_IMPLS    0.644320
# ar.L2.NUM_PERS_IMPLS    0.019753
# ma.L1.NUM_PERS_IMPLS   -0.481594
# dtype: float64

# %%
# MODELO ARMA(2,2)
training_armamod22 = sm.tsa.ARMA(training_df_series_tiempo, (2,2), freq='H')
training_res_armamod22 = training_armamod22.fit(method='mle', trend='c', disp=True)

# Parámetros estimados
print(training_res_armamod22.params)
# Out:
# const                   2.376177
# ar.L1.NUM_PERS_IMPLS    0.016545
# ar.L2.NUM_PERS_IMPLS    0.488423
# ma.L1.NUM_PERS_IMPLS    0.165253
# ma.L2.NUM_PERS_IMPLS   -0.397175
# dtype: float64

# %%
# Step 2: produce one-step-ahead forecasts
fcast = training_res_armamod21.forecast()

# %%
type(fcast)
# Out:
# tuple

# %%
fcast
# Out:
# (array([2.85540024]), array([3.26047681]), array([[-3.53501687,  9.24581736]]))

# %%
# ?df_series_tiempo.reindex

# %%
# Step 3: compute root mean square forecasting error
#true = df_series_tiempo._reindex(fcast.index)
true = df_series_tiempo.reindex(fcast.index, copy=False)
error = true - fcast
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in _ensure_has_len(seq)
#    4979     try:
# -> 4980         len(seq)
#    4981     except TypeError:
#
# TypeError: object of type 'builtin_function_or_method' has no len()
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1585-ac8745793596> in <module>
#       1 # Step 3: compute root mean square forecasting error
#       2 #true = df_series_tiempo._reindex(fcast.index)
# ----> 3 true = df_series_tiempo.reindex(fcast.index, copy=False)
#       4 error = true - fcast
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     185         @wraps(func)
#     186         def wrapper(*args, **kwargs):
# --> 187             return func(*args, **kwargs)
#     188
#     189         if not PY2:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in reindex(self, *args, **kwargs)
#    3564         kwargs.pop('axis', None)
#    3565         kwargs.pop('labels', None)
# -> 3566         return super(DataFrame, self).reindex(**kwargs)
#    3567
#    3568     @Appender(_shared_docs['reindex_axis'] % _shared_doc_kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    3687         # perform the reindex on the axes
#    3688         return self._reindex_axes(axes, level, limit, tolerance, method,
# -> 3689                                   fill_value, copy).__finalize__(self)
#    3690
#    3691     def _reindex_axes(self, axes, level, limit, tolerance, method, fill_value,
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    3499         if index is not None:
#    3500             frame = frame._reindex_index(index, method, copy, level,
# -> 3501                                          fill_value, limit, tolerance)
#    3502
#    3503         return frame
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _reindex_index(self, new_index, method, copy, level, fill_value, limit, tolerance)
#    3507         new_index, indexer = self.index.reindex(new_index, method=method,
#    3508                                                 level=level, limit=limit,
# -> 3509                                                 tolerance=tolerance)
#    3510         return self._reindex_with_indexers({0: [new_index, indexer]},
#    3511                                            copy=copy, fill_value=fill_value,
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in reindex(self, target, method, level, limit, tolerance)
#    3598
#    3599         # GH7774: preserve dtype/tz if target is empty and not an Index.
# -> 3600         target = _ensure_has_len(target)  # target may be an iterator
#    3601
#    3602         if not isinstance(target, Index) and len(target) == 0:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in _ensure_has_len(seq)
#    4980         len(seq)
#    4981     except TypeError:
# -> 4982         return list(seq)
#    4983     else:
#    4984         return seq
#
# TypeError: 'builtin_function_or_method' object is not iterable

# %%
# Entrenamiento
# Constante de varianza de la media 2.42 (previsiblemente ruido blanco)
arma_mod00 = sm.tsa.ARMA(df_series_tiempo, (0,0), freq='D').fit(method='mle', trend='c', disp=True)
print(arma_mod00.params)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1211-3f534cff326b> in <module>
#       1 # Entrenamiento
#       2 # Constante de varianza de la media 2.42 (previsiblemente ruido blanco)
# ----> 3 arma_mod00 = sm.tsa.ARMA(df_series_tiempo, (0,0), freq='D').fit(method='mle', trend='c', disp=True)
#       4 print(arma_mod00.params)
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py in __init__(self, endog, order, exog, dates, freq, missing)
#     433     def __init__(self, endog, order, exog=None, dates=None, freq=None,
#     434                  missing='none'):
# --> 435         super(ARMA, self).__init__(endog, exog, dates, freq, missing=missing)
#     436         exog = self.data.exog  # get it after it's gone through processing
#     437         _check_estimable(len(self.endog), sum(order))
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py in __init__(self, endog, exog, dates, freq, missing, **kwargs)
#      56
#      57         # Date handling in indexes
# ---> 58         self._init_dates(dates, freq)
#      59
#      60     def _init_dates(self, dates=None, freq=None):
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py in _init_dates(self, dates, freq)
#     191                         start=index[0], end=index[-1], freq=freq)
#     192                     if not inferred_freq and not resampled_index.equals(index):
# --> 193                         raise ValueError('The given frequency argument could'
#     194                                          ' not be matched to the given index.')
#     195                     index = resampled_index
#
# ValueError: The given frequency argument could not be matched to the given index.

# %%
# Posiblemente parámetro por término de ruido en observación estacionaria
arma_mod10 = sm.tsa.ARMA(prueba, (1,0), freq='H').fit(disp=False)
print(arma_mod10.params)

# %%
# Posiblemente parámetro por término de ruido en observación estacionaria
arma_mod11 = sm.tsa.ARMA(prueba, (1,1), freq='H').fit(disp=False)
print(arma_mod11.params)

# %%
print(arma_mod21.aic, arma_mod21.bic, arma_mod21.hqic)

# %%
print(arma_mod21.summary())

# %%
print(arma_mod21.summary2())

# %%
sm.stats.durbin_watson(arma_mod21.resid.values)

# %%
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
ax = arma_mod21.resid.plot(ax=ax);

# %%
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
ax = arma_mod30.resid.plot(ax=ax);

# %%
resid = arma_mod21.resid

# %%
stats.normaltest(resid)

# %%
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
fig = qqplot(resid, line='q', ax=ax, fit=True)

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(resid.values.squeeze(), lags=168, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(resid, lags=168, ax=ax2)

# %%
prueba.shape

# %%
resid.shape

# %%
r,q,p = sm.tsa.acf(resid.values.squeeze(), nlags=168, fft=True, qstat=True)

# %%
r.shape

# %%
#r,q,p = sm.tsa.acf(resid.values.squeeze(), fft=True, qstat=True)
prueba = np.c_[range(1,169), r[1:], q, p]
table = pd.DataFrame(prueba, columns=['lag', "AC", "Q", "Prob(>Q)"])
#print(table.set_index('lag'))
table.set_index('lag').head(3)

# %%
predict_num_pers_impls = arma_mod21.predict(dynamic=True)
#print(predict_num_pers_impls)
predict_num_pers_impls.head(3)

# %%
predict_num_pers_impls.shape

# %%
predict_num_pers_impls.count()

# %%
fig, ax = plt.subplots(figsize=(12, 8))
ax = prueba.index[0:].plot(ax=ax)
fig = arma_mod21.plot_predict(dynamic=True, ax=ax, plot_insample=False)

# %%
########### SEGUNDA ETAPA: estimar los coeficientes/parámetros de los términos 
# autorregresivos (AR) y de media móvil (MA) del modelo.
#La estimación maxima de verosimilitud (MLE) es un metodo estadístico para ajustando un modelo a los datos y provee estimaciones para los parámetros del modelo.
#mean es el modelo de la media (ej. mu)
#sigma es desviación estándar del modelo residual/innovaciones.
#El orden de parámetros en el argumento de entrada - phi - determina el orden del componente AR.
#* comenzando con el lag más bajo
#El orden de parámetros en el argumento de entrada- theta - determina el orden del componente MA.
#* comenzando por el lag más bajo
#--- LE MODELO ES ESTABLE?

# %%
#from statsmodels.tsa.arima_model import ARIMA
#model = ARIMA(prueba, order=(168,24,1))
#model_fit = model.fit()
#output = model_fit.forecast()
#yhat = output[0]

# %%
# Limpiar serie temporal antes de analizar tendencia y estacionalidad de comportamientos no deseados (sesgos),
# varianzas desiguales para corregir la no linealidad en la relación (mejorar correlación entre las variables). 
# Comprobar si es heterocedástica (no es constante en varianza); es frecuente observar que la varianza 
# aumenta con el nivel de la serie. Por lo tanto no sigue una distribución normal
# es recomendable realizar alguna de las siguientes transformaciones para acercarse más a una distribución normal:
# a) Transformación logarítmica: expandir valores pequeños y contraer los grandes
# b) Transformación de Box-Cox: lambda para aumentar la normalidad.

# %%
# BOX JENKINS con ARMA

# %%
####### aqui

# %%
##############################

# %%
# Creamos un objeto ARIMA Model para una configuración determinada (P, D, Q) 
# y lo entrenamos en nuestros datos utilizando el método fit:
from statsmodels.tsa.arima_model import ARIMA
order_212 = (2, 1, 2)
model_212 = ARIMA(df_series_tiempo, order_212, freq='H')
fit = model_212.fit()

# %%
# Devuelve un objeto ARIMAResults que es de interés. Podemos comprobar la calidad de nuestro modelo:
fit.summary()

# %%
fit.summary2()

# %%
# Y podemos estimar aproximadamente cómo se distribuyen los residuos:
residuals = pd.DataFrame(fit.resid, columns=['residuals'])
residuals.plot(kind='kde')

# %%
# ?fit.predict

# %%
# Predicción
# Si estamos satisfechos con nuestro modelo, entonces podemos predecir algunos datos dentro o fuera de la muestra.
# Esto se puede hacer con el método predict que, de forma predeterminada, devuelve la variable 
# endógena diferenciada, no la variable endógena en sí. Para cambiar este comportamiento, debemos 
# especificar typ = ‘niveles’.
# VARIABLE ENDÓGENA: valor que está determinado por las relaciones establecidas dentro del modelo 
preds = fit.predict(744, 1488, typ='levels')
# Entonces nuestras predicciones tienen los mismos niveles de nuestros datos de entrenamiento:
preds.plot(figsize=(20,4));

# %%
# A continuación, se utilizan los métodos ion() y ioff() que activan o desactivan
# el modo interactivo de dibujo para añadir, o no, nuevos datos sobre el gráfico actual. 
df_series_tiempo.plot(figsize=(20,4))   # Dibuja el gráfico

plt.xlabel("Fechas")   # Inserta el título del eje X
plt.ylabel("Personas")   # Inserta el título del eje Y
plt.ioff()   # Desactiva modo interactivo de dibujo

preds.plot(figsize=(20,4));   # No dibuja datos de lista2
plt.ion()   # Activa modo interactivo de dibujo
preds.plot(figsize=(20,4));   # Dibuja datos de lista2 sin borrar datos de lista1

# %%
# ?df_series_tiempo.plot

# %%
# Además, si nos interesa tener también intervalos de confianza, podemos usar el método forecast.
# Argumento de cadena
# También es posible alimentar predicciones con cadenas 
# (siempre use el formato ISO-8601 si desea evitar problemas) u objetos de fecha y hora:
## preds = fit.predict("2001-11-02", "2001-12-15", typ='levels')
# Funciona como se espera en StatsModels 0.9.0:
import statsmodels as sm
sm.__version__ # '0.9.0'

# %%
####### FINAL
